# %% [markdown]
# Loading data

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
from collections import defaultdict
from pymongo import MongoClient

# %%
k = 100 # Parameter: take every k-th top level element
SAMPLE_FILE = "mapsimple.xml"
xmlFile = "map.xml"

def get_element(xml_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(xml_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(xmlFile)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')

#Changing this regex to match brasilian names of streets
street_type_re = re.compile(r'^\b\S+\.?', re.IGNORECASE)
street_types = defaultdict(set)


expected = [u"Rua", u"Avenida", u"Travessa", u"Beco", u"Rodovia", u"Estrada", u"Logradouro", u"Viela", u"Alameda", u"Via", u"Praça"]

# UPDATE THIS VARIABLE
mapping = { "R": "Rua",
            "R.": "Rua",
            "r." : "Rua",
            "rua": "Rua",
            "RUA": "Rua",
            "Rua-": "Rua ",
            "Ruas": "Rua",
            "Av.": "Avenida",
            "AV.": "Avenida",
            "AVENIDA":"Avenida",
            "Alamenda": "Alameda",
            "Rodovoa": "Rodovia"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        node["type"]=element.tag        
        
        for at in element.attrib:
            if at in CREATED :
                if node.get("created") == None:
                    node[u"created"] = {}
                node[u"created"].update({at : element.get(at)})
            elif at in "lon":
                if node.get("pos") ==None:
                    node[u"pos"] = [0,1]
                node[u"pos"][1] = float(element.get(at))
            elif at in "lat":
                if node.get("pos") ==None:
                    node[u"pos"] = [0,1]
                node[u"pos"][0]= float(element.get(at))
            else: 
                node[at] = element.get(at)
        for child in element:
            
            if child.get("k"):      
                if problemchars.search(child.get("k")):
                    continue                    
                elif re.search(':',child.get("k")) != None:
                    name = child.get("k").split(":")
                    if node.get(name[0]) == None:                            
                        node[name[0]] = {}
                    if name[1]==u"street":
                        audit_street_type(street_types, child.get("v"))
                    node[name[0]].update({name[1] : child.get("v")})                            
                else:
                    if node.get("caract")==None:
                        node[u"caract"]={}                        
                    node[u"caract"].update({child.get("k"):child.get("v")})
            if element.tag == "way":                
                if child.tag == "nd":                     
                    if node.get("node_refs") == None:
                        node[u"node_refs"] = []
                    node[u"node_refs"].append(child.get("ref"))                       
            
        return node
    else:
        return None

def key_type(element, keys):
    if element.tag == "way":
        for tag in element.iter("tag"):
            k = tag.get("k")
            if lower.search(k):
                keys['lower'] +=1
            elif lower_colon.search(k):
                keys['lower_colon'] +=1
            elif problemchars.search(k):
                keys['problemchars'] +=1
            else:
                keys['other'] +=1
    
    return keys    

def process_keys(file_in):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for event, element in ET.iterparse(file_in, events=("start",)):
        keys = key_type(element, keys)
        
    return keys    
    
    
def process_map(file_in, pretty = False):
    #street_types = defaultdict(set)
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def update_name(name):
    m = street_type_re.search(name)
    if m:
        if m in mapping:
            name = name.replace(m.group(), mapping[m.group()])
    
    return name

def audit_street_name(data):
    for tupla in data:        
        if tupla.get('addr'):                   
            if tupla.get('addr').get('street'):
                name = tupla.get('addr').get('street')
                tupla.get('addr')['street'] = update_name(name)

# %%
data = process_map(xmlFile, True)
audit_street_name(data)

# %%
pprint.pprint(data[300110])
# Out:
# {u'caract': {'highway': 'residential', 'name': 'Rua RPB 01'},
#  u'created': {'changeset': '32026685',
#               'timestamp': '2015-06-17T11:21:55Z',
#               'uid': '2647840',
#               'user': 'geocorreiosgo',
#               'version': '2'},
#  'id': '308073677',
#  u'node_refs': ['3133517231', '3133517190'],
#  'type': 'way'}

# %%
    client = MongoClient("mongodb://localhost:27017")
    db = client['goiania']
    db.goiania.drop();

# %%
print db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'goiania')

# %%
db.goiania.insert_many(data)
print db.goiania.find_one()
# Out:
# {u'name': {u'el': u'\u0393\u03ba\u03bf\u03ca\u03ac\u03bd\u03b9\u03b1', u'en': u'Goi\xe2nia', u'zh': u'\u6208\u4e9a\u5c3c\u4e9a', u'ce': u'\u0413\u043e\u044f\u043d\u0438', u'ar': u'\u063a\u0648\u064a\u0627\u0646\u064a\u0627', u'ru': u'\u0413\u043e\u044f\u043d\u0438\u044f', u'pt': u'Goi\xe2nia', u'lv': u'Gojanija', u'lt': u'Gojanija', u'th': u'\u0e42\u0e01\u0e22\u0e32\u0e40\u0e19\u0e35\u0e22', u'tg': u'\u0413\u043e\u044f\u043d\u0438\u044f', u'pl': u'Goi\xe2nia', u'be': u'\u0413\u0430\u044f\u043d\u0456\u044f', u'bg': u'\u0413\u043e\u044f\u043d\u0438\u044f', u'de': u'Goi\xe2nia', u'fa': u'\u06af\u0648\u06cc\u0627\u0646\u06cc\u0627', u'hy': u'\u0533\u0578\u0575\u0561\u0576\u056b\u0561', u'ja': u'\u30b4\u30a4\u30a2\u30cb\u30a2', u'he': u'\u05d2\u05d5\u05d0\u05d9\u05d0\u05e0\u05d9\u05d4', u'ka': u'\u10d2\u10dd\u10d8\u10d0\u10dc\u10d8\u10d0', u'uz': u'Goyaniya', u'kk': u'\u0413\u043e\u044f\u043d\u0438\u044f', u'sr': u'\u0413\u043e\u0458\u0430\u043d\u0438\u0458\u0430', u'mn': u'\u0413\u043e\u044f\u043d\u0438\u044f', u'ko': u'\uace0\uc774\uc544\ub2c8\uc544', u'mk': u'\u0413\u043e\u0458\u0430\u043d\u0438\u0458\u0430', u'sh': u'Gojanija', u'uk': u'\u0413\u043e\u044f\u043d\u0456\u044f', u'mr': u'\u0917\u094b\u092f\u093e\u0928\u093f\u092f\u093e'}, u'created': {u'changeset': u'35519845', u'version': u'15', u'user': u'naoliv', u'timestamp': u'2015-11-22T23:24:55Z', u'uid': u'463507'}, u'caract': {u'website': u'http://www.goiania.go.gov.br/', u'population': u'1393579', u'name': u'Goi\xe2nia', u'wikipedia': u'pt:Goi\xe2nia', u'flag': u'http://upload.wikimedia.org/wikipedia/commons/b/be/Bandeira_de_Goi%C3%A2nia.svg', u'wikidata': u'Q83189', u'place': u'city', u'is_in': u'Goias, Brazil', u'state_capital': u'yes'}, u'pos': [-16.680882, -49.2532691], u'_id': ObjectId('5ac0e4b7659c2a221c56d4a8'), u'type': u'node', u'id': u'243850404', u'is_in': {u'country': u'Brazil', u'region': u'Centro Oeste', u'state': u'Goi\xe1s', u'country_code': u'BR', u'state_code': u'GO', u'continent': u'South America'}}

# %%
db.goiania.find().count()
# Out:
# 319027

# %%
user = db.goiania.distinct("created.user")

print len(user)
# Out:
# 385

# %%
#quantidade de contribuições por usuario
query = []
query.append({"$group" : {"_id" : "$created.user", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
query.append({"$limit" : 10})

result = db.goiania.aggregate(query)

for doc in result:
    pprint.pprint(doc)
# Out:
# {u'_id': u'street0501', u'count': 105016}
# {u'_id': u'greecemapper', u'count': 33594}
# {u'_id': u'geocorreiosgo', u'count': 32420}
# {u'_id': u'erickdeoliveiraleal', u'count': 32363}
# {u'_id': u'jeffersonbr', u'count': 13613}
# {u'_id': u'T\xfallio', u'count': 10010}
# {u'_id': u'Vilmar Amaral', u'count': 9005}
# {u'_id': u'taciofernandes', u'count': 8136}
# {u'_id': u'Dangoh', u'count': 6533}
# {u'_id': u'jdaraujo', u'count': 6172}

# %%
#usuario que mais contribuiu
query = []
query.append({"$group" : {"_id" : "$created.user", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
query.append({"$limit" : 1})

result = db.goiania.aggregate(query)

for doc in result:
    pprint.pprint(doc)
# Out:
# {u'_id': u'street0501', u'count': 105016}

# %%
#unique contributors
query = []

query.append({"$group" : {"_id" : "$created.user", "count":{"$sum":1}}})
query.append({"$match" : {"count" : 1}})

result = db.goiania.aggregate(query)
print len(list(db.goiania.aggregate(query))) 

for doc in result:
    pprint.pprint(doc)
# Out:
# 82
# {u'_id': u'Douglas Soares Pereira', u'count': 1}
# {u'_id': u'marthaleena', u'count': 1}
# {u'_id': u"DonomarBarber'Shop", u'count': 1}
# {u'_id': u'wambacher', u'count': 1}
# {u'_id': u'Paulo Henrique Rodrigues Oliveira', u'count': 1}
# {u'_id': u'Coyoty', u'count': 1}
# {u'_id': u'marciocr', u'count': 1}
# {u'_id': u'CentralDoXadrez', u'count': 1}
# {u'_id': u'Edmilson Pimentel', u'count': 1}
# {u'_id': u'P\xc9ROLA MULTI SERVICE', u'count': 1}
# {u'_id': u'J\xe9ssika Rodrigues', u'count': 1}
# {u'_id': u'Jeanlks', u'count': 1}
# {u'_id': u'Ewana', u'count': 1}
# {u'_id': u'Jean Moura', u'count': 1}
# {u'_id': u'Fabio De Carvalho Luz', u'count': 1}
# {u'_id': u'Jacob Neto', u'count': 1}
# {u'_id': u'Sousa807', u'count': 1}
# {u'_id': u'Marcos Pinheiro', u'count': 1}
# {u'_id': u'Alucard_c5', u'count': 1}
# {u'_id': u'soldado junior infantaria costa (malcriado)', u'count': 1}
# {u'_id': u'thetornado76', u'count': 1}
# {u'_id': u'Rui Alves Madalena', u'count': 1}
# {u'_id': u'Alverne Passos Barbosa', u'count': 1}
# {u'_id': u'Plotte F\xe1cil - Impress\xf5es', u'count': 1}
# {u'_id': u'Paul Smee', u'count': 1}
# {u'_id': u'Humberto Miranda', u'count': 1}
# {u'_id': u'Joao Paulo S Silva', u'count': 1}
# {u'_id': u'L\xfacio Couto', u'count': 1}
# {u'_id': u'Lucas Henrique', u'count': 1}
# {u'_id': u'joaodias', u'count': 1}
# {u'_id': u'Hitler Lynce Caetano', u'count': 1}
# {u'_id': u'Victor Basilio', u'count': 1}
# {u'_id': u'PlotteF\xe1cil Impress\xf5es', u'count': 1}
# {u'_id': u'Salom\xe3o', u'count': 1}
# {u'_id': u'Mapa Cultural de Goi\xe1s', u'count': 1}
# {u'_id': u'Janilson J\xfanior', u'count': 1}
# {u'_id': u'Hchehad', u'count': 1}
# {u'_id': u'Marcelo-CS', u'count': 1}
# {u'_id': u'PAULO ROBERTO FM', u'count': 1}
# {u'_id': u'nyuriks', u'count': 1}
# {u'_id': u'Acieg', u'count': 1}
# {u'_id': u'Hapachy kuarashi', u'count': 1}
# {u'_id': u'Victor Hugo Alves Da Rocha Costa', u'count': 1}
# {u'_id': u'EDSON SATO', u'count': 1}
# {u'_id': u'Wellington Mijolario', u'count': 1}
# {u'_id': u'Paulo P Costa Gomes', u'count': 1}
# {u'_id': u'ruthmaben', u'count': 1}
# {u'_id': u'Gustavorodrc', u'count': 1}
# {u'_id': u'viniciusgb4', u'count': 1}
# {u'_id': u'hofoen', u'count': 1}
# {u'_id': u'Yzsulap', u'count': 1}
# {u'_id': u'Silvio S Souza', u'count': 1}
# {u'_id': u'giokeppler', u'count': 1}
# {u'_id': u'Hotel Universo em Goiania', u'count': 1}
# {u'_id': u'Willian Brand\xe3o', u'count': 1}
# {u'_id': u'Nailton Modesto Rocha Camargo', u'count': 1}
# {u'_id': u'Arthtoach', u'count': 1}
# {u'_id': u'xRafasax', u'count': 1}
# {u'_id': u'Weuber Xavier', u'count': 1}
# {u'_id': u'werner2101', u'count': 1}
# {u'_id': u'WolfiDE', u'count': 1}
# {u'_id': u'veganflea', u'count': 1}
# {u'_id': u'Rodrigo Lisita', u'count': 1}
# {u'_id': u'Paulo Rog\xe9rio Cruz', u'count': 1}
# {u'_id': u'jenhag', u'count': 1}
# {u'_id': u'jwilliansilvabr', u'count': 1}
# {u'_id': u'mxpv', u'count': 1}
# {u'_id': u'Ergotelis', u'count': 1}
# {u'_id': u'mapper_07', u'count': 1}
# {u'_id': u'PRICIO', u'count': 1}
# {u'_id': u'Tom_Holland', u'count': 1}
# {u'_id': u'miltinho2016', u'count': 1}
# {u'_id': u'Joab Alves', u'count': 1}
# {u'_id': u'Gabriela Mendes', u'count': 1}
# {u'_id': u'Gabriel Giannotti', u'count': 1}
# {u'_id': u'Joao De Oliveira Rocha Silva', u'count': 1}
# {u'_id': u'mueschel', u'count': 1}
# {u'_id': u'desouzafilipe', u'count': 1}
# {u'_id': u'JCosta', u'count': 1}
# {u'_id': u'Edvaldo Adriany Silva Adriany', u'count': 1}
# {u'_id': u'ChrisTravuls', u'count': 1}
# {u'_id': u'Wesley Vilela', u'count': 1}

# %%
#quantidade de registro por tipo 
query = []
query.append({"$group" : {"_id" : "$type", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})

result = db.goiania.aggregate(query)

for doc in result:
    pprint.pprint(doc)
# Out:
# {u'_id': u'node', u'count': 267749}
# {u'_id': u'way', u'count': 51278}

# %%
#tipos de amenity
db.goiania.distinct("caract.amenity")
# Out:
# [u'place_of_worship',
#  u'hospital',
#  u'post_box',
#  u'school',
#  u'cinema',
#  u'pharmacy',
#  u'taxi',
#  u'fast_food',
#  u'theatre',
#  u'recycling',
#  u'Laborat\xf3rio',
#  u'atm',
#  u'restaurant',
#  u'bus_station',
#  u'post_office',
#  u'fuel',
#  u'cafe',
#  u'bank',
#  u'clinic',
#  u'car_rental',
#  u'arts_centre',
#  u'police',
#  u'car_wash',
#  u'toilets',
#  u'bicycle_parking',
#  u'bar',
#  u'university',
#  u'nightclub',
#  u'parking',
#  u'telephone',
#  u'prison',
#  u'childcare',
#  u'pub',
#  u'library',
#  u'college',
#  u'community_centre',
#  u'parking_entrance',
#  u'fountain',
#  u'shelter',
#  u'veterinary',
#  u'townhall',
#  u'internet_cafe',
#  u'bicycle_repair_station',
#  u'dentist',
#  u'charging_station',
#  u'embassy',
#  u'driving_school',
#  u'kindergarten',
#  u'bench',
#  u'marketplace',
#  u'food_court',
#  u'nursing_home',
#  u'courthouse',
#  u'fire_station',
#  u'club',
#  u'love_hotel',
#  u'public_building',
#  u'grave_yard',
#  u'studio']

# %%
#quantidade de registro por tipo 
query = []
query.append({"$group" : {"_id" : "$caract.amenity", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
query.append({"$limit" : 10})

result = db.goiania.aggregate(query)

for doc in result:
    pprint.pprint(doc)
# Out:
# {u'_id': None, u'count': 317771}
# {u'_id': u'parking', u'count': 165}
# {u'_id': u'fuel', u'count': 160}
# {u'_id': u'bank', u'count': 112}
# {u'_id': u'school', u'count': 98}
# {u'_id': u'place_of_worship', u'count': 88}
# {u'_id': u'fast_food', u'count': 80}
# {u'_id': u'restaurant', u'count': 78}
# {u'_id': u'pharmacy', u'count': 76}
# {u'_id': u'post_office', u'count': 54}

# %%
#ruas
db.goiania.distinct("addr.street")
# Out:
# [u'Rua 85',
#  u'Rua S 5',
#  u'Alameda Alfredo Lopes de Morais',
#  u'Avenida T-4',
#  u'Avenida Rep\xfablica do L\xedbano',
#  u'Avenida Primeira Radial',
#  u'Rua 261',
#  u'Avenida Rio Verde',
#  u'Rua Haroldo Barbosa',
#  u'Rua da Sa\xfade',
#  u'Avenida Goi\xe1s',
#  u'Avenida Quinta Avenida',
#  u'Rua Corumb\xe1',
#  u'Avenida T-7',
#  u'Rua 10',
#  u'Rua 14',
#  u'Avenida Jamel Cec\xedlio',
#  u'Avenida T-9',
#  u'Rua U-47',
#  u'Rua U-54',
#  u'Rua Mossor\xf3',
#  u'AV. N\xe1poli',
#  u'Rua 52',
#  u'Rua 54',
#  u'Avenida N\xe1poli',
#  u'Avenida Mil\xe3o',
#  u'Avenida dos Alpes',
#  u'Avenida Armando de Godoy',
#  u'Avenida Pio XII',
#  u'Avenida S\xe3o Paulo',
#  u'Pra\xe7a Doutor Pedro Ludovico Teixeira',
#  u'Rua 11 de Junho',
#  u'Avenida 24 de Outubro',
#  u'Rua R-7',
#  u'Avenida Pires Fernandes',
#  u'Rua S-1',
#  u'Rua C-137 (Continua\xe7\xe3o da T-10) esquina com Rua C-252',
#  u'Rua 18-A',
#  u'Rua C-159',
#  u'Rodovia GO-070, km 15,5.',
#  u'R. GB 19',
#  u'Rua GB-14',
#  u'Rua 107',
#  u'Avenida Circular',
#  u'Avenida da Independ\xeancia',
#  u'AVENIDA DOM ABEL',
#  u'Rua Antonio Gomes de Freitas',
#  u'Avenida Vereador Jos\xe9 Monteiro',
#  u'Avenida Independ\xeancia',
#  u'Avenida Anhanguera',
#  u'Avenida dos Guaicurus',
#  u'Rua da Conc\xf3rdia',
#  u'Rua C-252',
#  u'Rua 115 E',
#  u'Avenida B com Rua 9B',
#  u'Rua 230',
#  u'Avenida Rep\xfablica do Libano',
#  u'Rua J-6',
#  u'Rua 1.122',
#  u'Pra\xe7a do Cruzeiro',
#  u'Rua Coronel Di\xf3genes de Castro Ribeiro',
#  u'T-27',
#  u'Rua Neto',
#  u'Rodovia Br-153',
#  u'Rua Campinas',
#  u'Rua Victor Carvalho Ramos',
#  u'Rua 6',
#  u'rua 10',
#  u'Rua Dona Mariquinha',
#  u'Avenida Das Na\xe7\xf5es',
#  u'Rua Araponga, Quadra 23 Lote 16',
#  u'Avenida Domiciano Peixoto',
#  u'Avenida Vasco dos Reis, Quadra 17 Lote 03',
#  u'Avenida Castelo Branco',
#  u'Rodovia BR-153',
#  u'Rua 36',
#  u'Avenida 85',
#  u'Alameda Coronel Eug\xeanio Jardim',
#  u'Alameda Americano do Brasil',
#  u'Avenida Deputado Jamel Cec\xedlio esquina com a Rua 56',
#  u'Rua 56',
#  u'Avenida Pedro Ludovico',
#  u'Rua J 2',
#  u'Avenida W 2',
#  u'Rua J-11',
#  u'Rua 18',
#  u'Rua T-36',
#  u'Rua 11',
#  u'Avenida Marginal Botafogo',
#  u'Avenida Democratas',
#  u'Rua dos Araujos',
#  u'Rua-6',
#  u'Rua Venerando de Freitas Borges',
#  u'Avenida C\xe2mara Filho',
#  u'Avenida Cana\xe3',
#  u'Rua 246',
#  u'Rua 1131',
#  u'Avenida Mutir\xe3o',
#  u'Rua T-28',
#  u'Rua 226',
#  u'Qd20 Lt04',
#  u'Qd41 Lt',
#  u'Qd34 Lt01',
#  u'Qd 23 Lt 01',
#  u'Qd37 Lt02',
#  u'Qd40 Lt10',
#  u'Qd44 Lt02',
#  u'Qd44 Lt20',
#  u'Qd44 Lt18',
#  u'Qd43 L12',
#  u'Qd46 Lt04',
#  u'Qd48 Lt60',
#  u'Qd23 Lt05',
#  u'Qd23 Lt14',
#  u'Qd26 Lt',
#  u'Qd33 Lt35',
#  u'Qd48 Lt102',
#  u'Qd46 Lt10',
#  u'Qd48 Lt116',
#  u'Qd22 Lt01',
#  u'Qd37 Lt 21',
#  u'Qd33 L03',
#  u'Qd4 Lt10',
#  u'Rua C-131',
#  u'Rua C-147',
#  u'Rua JC-15',
#  u'Avenida Portugal',
#  u'Avenida Tocantins',
#  u'C.F.C. Cultura\n\nR. 1, 40 - St. Central, Goi\xe2nia - GO, 74013-010',
#  u'Rua T-27',
#  u'Avenida da Igualdade',
#  u'Rua Rio Verde',
#  u'Qd 46 Lt 10',
#  u'Avenida W 5',
#  u'Avenida das Bandeiras',
#  u'Rua C-259',
#  u'Avenida Monte Carlo',
#  u'Rua 101 Unidade 101',
#  u'Rua 67-B',
#  u'Rua RI 9',
#  u'Rua P 6',
#  u'Rua 200',
#  u'Rua Cabo Verde',
#  u'Avenida SC-1',
#  u'Rua Dona Sinh\xe1 Cupertino de Barros',
#  u'Rua L -15',
#  u'Rua 88',
#  u'Qd24 Lt2',
#  u'Travessa TR -1',
#  u'Rua da Divisa',
#  u'Avenida Desembargador El\xe1dio De Amorim',
#  u'Avenida T-63',
#  u'Avenida Afonso Pena',
#  u'Rua Diamantina',
#  u'Avenida Parana\xedba',
#  u'qd 14',
#  u'Avenida C-148',
#  u'Rua Doutor Olinto Manso Pereira',
#  u'Pra\xe7a Isabelina Naves Carneiro',
#  u'Avenida Teodomiro de Souza',
#  u'Rua Jos\xe9 Rodrigues De Morais',
#  u'Via Expressa Anel Vi\xe1rio',
#  u'Rua 208 A',
#  u'Rua Hugo Froes',
#  u'Rua Aroeira',
#  u'Rua Niter\xf3i',
#  u'Avenida Vicente De Paula Souza',
#  u'Rua Londrina',
#  u'Rua Manaus',
#  u'Rua Recife',
#  u'Rua Vit\xf3ria',
#  u'Rua Salvador',
#  u'Rua 5',
#  u'Rua Ernesto Luiz Furtado',
#  u'Rua Onze De Maio',
#  u'Avenida B',
#  u'Rua Nossa Senhora Auxiliadora',
#  u'Rua Jo\xe3o Batista De Toledo',
#  u'Avenida Dom Abel',
#  u'Rua Galena',
#  u'Rua Coronel Get\xfalio Artiaga Lima',
#  u'Rua Mica',
#  u'Rua Antim\xf4nio',
#  u'Rua Jales Guedes Coelho',
#  u'Avenida Escultor Veiga Vale',
#  u'Rua Baritinita',
#  u'Rua Professor Alfredo F. De Castro',
#  u'Rua Prustita',
#  u'Rua Cianita',
#  u'Rua Jo\xe3o Teixeira \xc1lvares J\xfanior',
#  u'Rua Corindon',
#  u'Rua H 152',
#  u'Rua L 22',
#  u'Rua L 6',
#  u'Rua L 18',
#  u'Avenida Senador Ant\xf4nio Ramos Caiado',
#  u'Rua Dona Antonieta Cupertino Barros de Amorim',
#  u'Avenida W-003',
#  u'Rua L 7',
#  u'Rua L 4',
#  u'Rua L 19',
#  u'Rua Doutor Odilon De Amorim',
#  u'Rua L-16',
#  u'Rua L 3',
#  u'Rua L 24',
#  u'Rua L 25',
#  u'Rua L 8',
#  u'Rua L 26',
#  u'Rua L 21-A',
#  u'Rua L 1',
#  u'Rua L 20',
#  u'Rua L 10',
#  u'Rua L 17',
#  u'Rua Estibinita',
#  u'Rua L 22-A',
#  u'Rua L 5',
#  u'Rua L 2',
#  u'Rua J 16',
#  u'Rua L 23',
#  u'Rua L 13',
#  u'Rua S\xe3o Carlos',
#  u'Rua Santo Amaro',
#  u'Rua Ji 16',
#  u'Rua Dourado',
#  u'Rua Ji 15',
#  u'Rua S\xe3o Caetano',
#  u'Rua Ji 17',
#  u'Rua Mg 16',
#  u'S\xe3o Marcos',
#  u'Rua Mg 20',
#  u'Rua S\xe3o Pedro',
#  u'Rua S\xe3o Gabriel',
#  u'Rua Mg 19',
#  u'Avenida JI 09',
#  u'Rua Mg 14',
#  u'Rua Mg 10',
#  u'Rua Mg 15',
#  u'Rua Lambari',
#  u'Rua Santo Agostinho',
#  u'Alameda Jo\xe3o Reis',
#  u'Rua S\xe3o Mateus',
#  u'Rua Mg 13',
#  u'Rua S\xe3o Domingos',
#  u'Rua Mg 12',
#  u'Rua Antonio S. Franqueiro',
#  u'Rua Madre Nely',
#  u'Avenida D\xe3o Cruz',
#  u'Avenida Major Oleg\xe1rio',
#  u'Rua Madre Gabriela',
#  u'Rua Peniel',
#  u'Rua Madre Francisca',
#  u'Avenida Doutor Jos\xe9 A. Neddermeyer',
#  u'Rua das Rosas',
#  u'Rua Flamboyant',
#  u'Ruas das Avencas',
#  u'Rua das Orqu\xeddeas',
#  u'Rua Samambaia',
#  u'Avenida Walquirira',
#  u'Rua Flemington',
#  u'Rua 03',
#  u'Rua Santa Luzia',
#  u'Rua Urbano Berqu\xf3',
#  u'Rua C',
#  u'Avenida V 8',
#  u'Avenida W 1',
#  u'Avenida dos Ferrovi\xe1rios',
#  u'Rua SIlimanita',
#  u'Rua Turmalina',
#  u'Rua H 107',
#  u'Rua Sodalita',
#  u'Rua S',
#  u'Rua J 60',
#  u'Rua J 24',
#  u'Rua J 13',
#  u'Travessa Hematita',
#  u'Rua J 38',
#  u'Rua J 9',
#  u'Rua J 15',
#  u'Rua J 40',
#  u'Travessa Pirita',
#  u'Rua J 84',
#  u'Rua R',
#  u'Rua J 22',
#  u'Rua J 7',
#  u'Rua Caolim',
#  u'Rua J 82',
#  u'Rua J 11',
#  u'Rua Granada',
#  u'Rua J',
#  u'Rua Y',
#  u'Rua J 72',
#  u'Rua J 1',
#  u'Rua Magnetita',
#  u'Rua J 14',
#  u'Rua J 34',
#  u'Rua Gipsita',
#  u'Rua Ep\xeddoto',
#  u'Alameda Dos Gansos',
#  u'Alameda Dos Patos',
#  u'Avenida Uirapuru',
#  u'Rua Dos Albatrozes',
#  u'Rua Q',
#  u'Rua Dos Bem-Te-Vis',
#  u'Rua Papagaios',
#  u'Rua Dos Can\xe1rios',
#  u'Rua X 5',
#  u'Rua Das Arapongas',
#  u'Rua dos Gavi\xf4es',
#  u'Rua Dos Cardeais',
#  u'Rua X 9',
#  u'Rua X 13',
#  u'Rua X 14',
#  u'Rua Patativas',
#  u'Rua Dos Fais\xf5es',
#  u'Rua Das Andorinhas',
#  u'Rua X 7',
#  u'Rua Das \xc1guias',
#  u'Rua X 11',
#  u'Rua Z',
#  u'Rua P',
#  u'Rua Dos Curi\xf3s',
#  u'Rua Das Gaivotas',
#  u'Ruas Das Juritis',
#  u'Rua J 21',
#  u'Rua J 56',
#  u'Alameda Dos Cisnes',
#  u'Rua Das Siriemas',
#  u'Rua J 70',
#  u'Rua Das Gar\xe7as',
#  u'Rua B',
#  u'Rua Das Juritis',
#  u'Rua A',
#  u'Rua dos Curi\xf3s',
#  u'Rua J 78',
#  u'Rua J 44',
#  u'Rua J 32',
#  u'Rua Guriatas',
#  u'Rua J 66',
#  u'Rua Dos Main\xe1s',
#  u'Rua Dos Tucanos',
#  u'Rua X 10',
#  u'Rua Dos Inhambus',
#  u'Rua T',
#  u'Rua J 42',
#  u'Rua das Juru\xe1s',
#  u'Rua J 54',
#  u'Rua E',
#  u'Rua X 8',
#  u'Rua V',
#  u'Rua J 68',
#  u'Rua H',
#  u'Rua F',
#  u'Rua X 6',
#  u'Rua G',
#  u'Rua I',
#  u'Rua N',
#  u'Rua X 12',
#  u'Rua L',
#  u'Avenida Osvaldo Cruz',
#  u'Rua X 3',
#  u'Rua Para\xedba',
#  u'Avenida Itamarati',
#  u'Rua R 2',
#  u'Avenida 107',
#  u'Rua 16',
#  u'Rua R 1',
#  u'Rua R 14',
#  u'Rua R 4',
#  u'Rua R 5',
#  u'Rua X 22',
#  u'Rua 13',
#  u'Rua R 6',
#  u'Rua X 19',
#  u'Rua R 7',
#  u'Rua X 17',
#  u'Rua dos Tico-Ticos',
#  u'Rua R 11',
#  u'Avenida 100',
#  u'Rua R 9',
#  u'Avenida 101',
#  u'Rua Dos Mutuns',
#  u'Rua X 23',
#  u'Rua Das Perdizes',
#  u'Rua R 13',
#  u'Rua R 10',
#  u'Avenida 102A',
#  u'Rua Dos Marrecos',
#  u'Rua X 20',
#  u'Rua Dos Sabi\xe1s',
#  u'Avenida 102',
#  u'Avenida 103',
#  u'Avenida 105',
#  u'Avenida 104',
#  u'Avenida 106',
#  u'Rua Dos Rouxin\xf3is',
#  u'Rua 12',
#  u'Rua Dos Pombos',
#  u'Rua Dos Tangar\xe1s',
#  u'Rua Dos Pelicanos',
#  u'Rua R 11;Rua R 11-A',
#  u'Rua 10A',
#  u'Rua R 3',
#  u'Rua R 12',
#  u'Rua Bar\xe3o de Fran\xe7a',
#  u'Viela Brasil 4',
#  u'Viela Brasil 1',
#  u'Rua Padre Orc\xe9lio',
#  u'Avenida Rio Branco',
#  u'Rua Bras\xedlia',
#  u'Rua Veneza',
#  u'Viela C',
#  u'Avenida Buenos Aires',
#  u'Rua Lisboa',
#  u'Avenida R 7',
#  u'Rua C 49',
#  u'Viela D',
#  u'Rua C 36',
#  u'Rua Atenas',
#  u'Rua Augusta',
#  u'Rua Lima',
#  u'Rua C 41',
#  u'Avenida Jovita Maria De Jesus',
#  u'Avenida T\xf3quio',
#  u'Rua Nova Delhi',
#  u'Viela A',
#  u'Rua C 37',
#  u'Rua Quito',
#  u'Avenida C 2',
#  u'Rua Timbo',
#  u'Avenida Benedito Silvestre De Toledo',
#  u'Rua 43',
#  u'Rua C 21',
#  u'Rua 70 C',
#  u'Rua Maria Cristina De Morais',
#  u'Rua Regina',
#  u'Rua C 39',
#  u'Viela B',
#  u'Avenida R 2',
#  u'Rua C 11',
#  u'Avenida R 5',
#  u'Rua Damasco',
#  u'Rua 50',
#  u'Avenida Senegal',
#  u'Rua Moscou',
#  u'Rua Ant\xf4nio Carlos Tavares De Morais',
#  u'Rua C 45',
#  u'Rua Nevada',
#  u'Rua Tapaj\xf3s',
#  u'Rua Assun\xe7\xe3o',
#  u'Avenida da Luz',
#  u'Avenida C 6',
#  u'Rua C 48',
#  u'Rua C 44',
#  u'Rua Beira Alta',
#  u'Rua C 47',
#  u'Rua 70 B',
#  u'Rua C\xf3rsega',
#  u'Rua Carlos Alberto Tavares de morais',
#  u'Rua Montreal',
#  u'Rua Canecas',
#  u'Rua Chipre',
#  u'Rua Da P\xe1scoa',
#  u'Rua Madrid',
#  u'Rua C 23',
#  u'Avenida R 1',
#  u'Rua Argel',
#  u'Rua C 40',
#  u'Rua da P\xe1scoa',
#  u'Rua C 8',
#  u'Rua C 25',
#  u'Rua Montevid\xe9o',
#  u'Rua C 43',
#  u'Rua Toledo',
#  u'Rua C 9',
#  u'Rua C-1',
#  u'Rua Valen\xe7a',
#  u'Rua C 10',
#  u'Rua Havana',
#  u'Rua C 27',
#  u'Avenida Porto Rico',
#  u'Rua C 29',
#  u'Rua Berlim',
#  u'Rua C 26',
#  u'Rua Santiago',
#  u'Rua Can\xe1rias',
#  u'Alameda Do Nascente',
#  u'Avenida Rodolfo Tavares De Morais',
#  u'Rua C 12',
#  u'Avenida C 5',
#  u'Avenida Porto Pr\xedncipe',
#  u'Rua Albatroz',
#  u'Rua Curitiba',
#  u'Alameda Rui Rodrigues De Morais',
#  u'Rua 62',
#  u'Rua C 2',
#  u'Rua Carlos Magno',
#  u'Rua Zacarias Alves Lima',
#  u'Rua Dante Alighiere',
#  u'Rua Benedita Leal P\xf3voa',
#  u'Rua Marco T\xfalio',
#  u'Rua J\xfalio C\xe9sar',
#  u'Rua Geraldo Oleg\xe1rio Da Cruz',
#  u'Rua Tito L\xedvio',
#  u'Rua Professor Alcides Ramos Jub\xe9',
#  u'Avenida Cristus',
#  u'Alameda Jovita Farias',
#  u'Rua C 17',
#  u'Rua Tib\xe9rio',
#  u'Rua C 13',
#  u'Rua Wilson Alves Ferreira',
#  u'Rua Pompeu',
#  u'Rua Goi\xe2nia',
#  u'Rua Dona Augusta Garavelo',
#  u'Rua Dona Maria Galv\xe3o Pinheiro',
#  u'Rua Rio Sena',
#  u'Rua Cris\xe2ntemos',
#  u'Rua Costa e Silva',
#  u'Rua Tulipas',
#  u'Avenida Silvestre Golveia',
#  u'Rua Tilias',
#  u'Rua D\xe1lias',
#  u'Rua Pet\xfanias',
#  u'Rua Violetas',
#  u'Rua Ger\xe2nios',
#  u'Rua Hort\xeansias',
#  u'Rua Ac\xe1cias',
#  u'Rua Amar\xedlis',
#  u'Rua Primeiro De Maio',
#  u'Rua R 1 A',
#  u'Rua Mutum',
#  u'Rua Tangar\xe1',
#  u'Rua 22',
#  u'Rua 30',
#  u'Rua 8 (Quadras 39 A 44)',
#  u'Rua 52 B',
#  u'Rua 69-A',
#  u'Rua 70',
#  u'Rua Uni\xe3o',
#  u'Rua 51 B',
#  u'Rua 69 B',
#  u'Rua 53',
#  u'Rua 72',
#  u'Rua 69',
#  u'Rua 55',
#  u'Rua Ant\xf4nio Louren\xe7o Ribeiro',
#  u'Rua Pelicano',
#  u'Alameda Dona Gercina',
#  u'Rua Galo Da Serra',
#  u'Rua 51',
#  u'Rua Olivina',
#  u'Rua Nova York',
#  ...]

# %%
query = []
query.append({"$match":{"addr.street": {"$eq": "Qd4 Lt10"}}})

result = db.goiania.aggregate(query)

for doc in result:
    pprint.pprint(doc)
# Out:
# {u'_id': ObjectId('5ab983cd659c2a16ec184f27'),
#  u'addr': {u'street': u'Qd4 Lt10'},
#  u'caract': {u'craft': u'tailor',
#              u'name': u'Maristela Quinta',
#              u'opening_hours': u'Th 07:30-16:00'},
#  u'created': {u'changeset': u'50282627',
#               u'timestamp': u'2017-07-14T13:05:08Z',
#               u'uid': u'6265328',
#               u'user': u'MGMorais',
#               u'version': u'1'},
#  u'id': u'4970393722',
#  u'pos': [-16.755721, -49.176259],
#  u'type': u'node'}

# %%
#trazendo todas as ruas que começam com qd
#mostrar esses problemas no banco
result = db.goiania.find({"addr.street": {'$regex': '^Qd', '$options': 'i'}})
print db.goiania.find({"addr.street": {'$regex': '^Qd', '$options': 'i'}}).count()
print db.goiania.find({"addr.street": {'$regex': '^Qd', '$options': 'i'}}).distinct("created.user")
for doc in result:
    print pprint.pprint(doc)
# Out:
# 29
# [u'MGMorais', u'erickdeoliveiraleal']
# {u'_id': ObjectId('5ac0e4ba659c2a221c5aa9c4'),
#  u'addr': {u'street': u'Qd20 Lt04'},
#  u'caract': {u'historic': u'castle',
#              u'name': u'Carla TER\xc7A SEXTA',
#              u'opening_hours': u'Tu, Fr 07:30-16:00'},
#  u'created': {u'changeset': u'50281768',
#               u'timestamp': u'2017-07-14T12:20:05Z',
#               u'uid': u'6265328',
#               u'user': u'MGMorais',
#               u'version': u'3'},
#  u'id': u'4953787721',
#  u'pos': [-16.746967, -49.1752213],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c

#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5ae8c8'),
#  u'addr': {u'street': u'qd 14'},
#  u'caract': {u'craft': u'tailor', u'name': u'Eloisa 2\xaa/4\xaa/6\xaa'},
#  u'created': {u'changeset': u'56703304',
#               u'timestamp': u'2018-02-26T21:15:15Z',
#               u'uid': u'6265328',
#               u'user': u'MGMorais',
#               u'version': u'1'},
#  u'id': u'5438438921',
#  u'pos': [-16.746536, -49.1723087],
#  u'type': u'node'}
# None

# %%
string = "74.110-100"
print re.match(r"^74\.?\d{3}\-?\d{3}$", string)
#"^74[0-9\-]{6:7}"
# Out:
# <_sre.SRE_Match object at 0x0000000013BAB780>

# %%
        
#count quantidade de tags de enderecos
print db.goiania.find({"addr": {'$exists': True}}).count()           
#count quantidade de tags de enderecos com ruas
print db.goiania.find({"addr.street": {'$exists': True}}).count()
#checar se os postcodes estao no padrao
print db.goiania.find({"addr.postcode":{'$exists':True}}).count()
#postcodes = db.goiania.find({"addr.postcode":{'$exists':True}})
#postcodes = db.goiania.find({"addr.postcode":{'$exists':True, "$not": re.compile(r"^74(\d|\-|\.){6,8}")}})
print db.goiania.find({"addr.postcode":{'$exists':True, "$not": re.compile(r"^74\.?\d{3}\-?\d{3}$")}}).count()
postcodes = db.goiania.find({"addr.postcode":{'$exists':True, "$not": re.compile(r"^74\.?\d{3}\-?\d{3}$}")}})
#for doc in postcodes:
    #print pprint.pprint(doc)
#se os postcodes nao estao no padrao checar a cidade addr.city
print db.goiania.find({"addr.postcode":{'$exists':True, "$not": re.compile(r"^74\.?\d{3}\-?\d{3}$")}}).distinct("addr.city")
# Out:
# 3246
# 3000
# 167
# 12
# [u'Goianira', u'Santo Ant\xf4nio de Goi\xe1s', u'Trindade', u'Santo Antonio de Goi\xe1s']

# %%
#amenity: restaurant cousine
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'restaurant'}}).distinct("caract.cuisine")
#most frequent cuisine 
query = []
query.append({"$match":{"caract.amenity":{"$exists": True, "$eq": u'restaurant'}}})
query.append({"$group" : {"_id" : "$caract.cuisine", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
cuisine = db.goiania.aggregate(query)
for doc in cuisine:
    print pprint.pprint(doc)

#amenity: postal_office user geocorreios
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'post_office'}}).distinct("created.user")

#addr suburb (bairro)
print db.goiania.find({"addr.suburb":{"$exists": True}}).count()
query = []
query.append({"$match":{"addr.suburb":{"$exists": True}}})
query.append({"$group" : {"_id" : "$addr.suburb", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
bairros = db.goiania.aggregate(query)                                          
for doc in bairros:
    print pprint.pprint(doc)
# Out:
# [u'barbecue', u'japanese', u'pizza', u'steak_house;burger', u'chinese', u'pasta', u'regional', u'italian', u'international', u'burger', u'barbecue;steak_house;brazilian', u'vegetarian', u'barbecue;japanese', u'chinese;oriental', u'steak_house']
# {u'_id': None, u'count': 47}
# None
# {u'_id': u'pizza', u'count': 6}
# None
# {u'_id': u'regional', u'count': 5}
# None
# {u'_id': u'burger', u'count': 3}
# None
# {u'_id': u'japanese', u'count': 3}
# None
# {u'_id': u'barbecue', u'count': 3}
# None
# {u'_id': u'international', u'count': 2}
# None
# {u'_id': u'chinese;oriental', u'count': 1}
# None
# {u'_id': u'barbecue;japanese', u'count': 1}
# None
# {u'_id': u'barbecue;steak_house;brazilian', u'count': 1}
# None
# {u'_id': u'vegetarian', u'count': 1}
# None
# {u'_id': u'steak_house;burger', u'count': 1}
# None
# {u'_id': u'pasta', u'count': 1}
# None
# {u'_id': u'steak_house', u'count': 1}
# None
# {u'_id': u'chinese', u'count': 1}
# None
# {u'_id': u'italian', u'count': 1}
# None
# [u'geocorreiosgo', u'charasman', u'T\xfallio', u'jdaraujo', u'santamariense', u'RCRibeiro22', u'Fausto Almeida', u'Andr\xe9 Alvarenga', u'Adellane', u'Dangoh']
# 2863
# {u'_id': u'Independ\xeancia - 1\xba Complemento Setor das Mans\xf5es',
#  u'count': 108}
# None
# {u'_id': u'Mans\xf5es Para\xedso', u'count': 94}
# None
# {u'_id': u'Vila Oliveira', u'count': 85}
# None
# {u'_id': u'Parque das Na\xe7\xf5es', u'count': 82}
# None
# {u'_id': u'Expansul', u'count': 82}
# None
# {u'_id': u'Parque Veiga Jardim', u'count': 81}
# None
# {u'_id': u'Jardim Tiradentes', u'count': 78}
# None
# {u'_id': u'Colina Azul', u'count': 69}
# None
# {u'_id': u'Retiro do Bosque', u'count': 62}
# None
# {u'_id': u'Setor Ponta Kayana', u'count': 58}
# None
# {u'_id': u'Setor Serra Dourada - 3\xaa Etapa', u'count': 50}
# None
# {u'_id': u'Independ\xeancia - 3\xba Complemento', u'count': 50}
# None
# {u'_id': u'Cidade Livre', u'count': 49}
# None
# {u'_id': u'Setor Santo Andr\xe9', u'count': 48}
# None
# {u'_id': u'Jardim Dom Bosco 2\xaa Etapa', u'count': 45}
# None
# {u'_id': u'Setor Pontakayana', u'count': 45}
# None
# {u'_id': u'Jardim Boa Esperan\xe7a', u'count': 42}
# None
# {u'_id': u'Villa Romana', u'count': 42}
# None
# {u'_id': u'Jardim Riviera', u'count': 41}
# None
# {u'_id': u'Residencial Village Garavelo', u'count': 41}
# None
# {u'_id': u'P\xf3lo Empresarial Goi\xe1s', u'count': 40}
# None
# {u'_id': u'Jardim Cristal', u'count': 40}
# None
# {u'_id': u'Itapo\xe3', u'count': 40}
# None
# {u'_id': u'Morada dos P\xe1ssaros', u'count': 39}
# None
# {u'_id': u'Setor Conde dos Arcos - Complemento', u'count': 39}
# None
# {u'_id': u'Pontal Sul - Acr\xe9scimo', u'count': 39}
# None
# {u'_id': u'Jardim Maranata', u'count': 36}
# None
# {u'_id': u'Jardim Veneza', u'count': 33}
# None
# {u'_id': u'Setor Marista Sul', u'count': 31}
# None
# {u'_id': u'Papillon Park', u'count': 31}
# None
# {u'_id': u'Setor Colonial Sul', u'count': 30}
# None
# {u'_id': u'Vera Cruz', u'count': 30}
# None
# {u'_id': u'Residencial Village Garavelo - 2\xaa Etapa', u'count': 29}
# None
# {u'_id': u'Villa Delfiore', u'count': 28}
# None
# {u'_id': u'Jardim S\xe3o Conrado', u'count': 28}
# None
# {u'_id': u'Independ\xeancia', u'count': 28}
# None
# {u'_id': u'Independ\xeancia - 2\xba Complemento', u'count': 27}
# None
# {u'_id': u'Jardim Dom Bosco', u'count': 27}
# None
# {u'_id': u'American Park', u'count': 27}
# None
# {u'_id': u'Jardim Belo Horizonte', u'count': 26}
# None
# {u'_id': u'Jardim das Cascatas', u'count': 23}
# None
# {u'_id': u'Setor Central', u'count': 23}
# None
# {u'_id': u'Parque Hayala', u'count': 22}
# None
# {u'_id': u'Industrial Santo Ant\xf4nio', u'count': 22}
# None
# {u'_id': u'Conjunto Habitacional Madre Germana - 1\xaa Etapa', u'count': 21}
# None
# {u'_id': u'Papillon Park - Complemento', u'count': 21}
# None
# {u'_id': u'Jardim Floren\xe7a', u'count': 21}
# None
# {u'_id': u'Jardim dos Girass\xf3is', u'count': 20}
# None
# {u'_id': u'Jardim Ip\xea', u'count': 20}
# None
# {u'_id': u'Setor Conde dos Arcos', u'count': 20}
# None
# {u'_id': u'Nova Cidade', u'count': 19}
# None
# {u'_id': u'Porto das Pedras', u'count': 19}
# None
# {u'_id': u'Jardim Bela Morada', u'count': 18}
# None
# {u'_id': u'Jardim Monte Cristo', u'count': 18}
# None
# {u'_id': u'Jardim Boa Esperan\xe7a - Continua\xe7\xe3o', u'count': 17}
# None
# {u'_id': u'Setor Residencial Campos El\xedsios', u'count': 17}
# None
# {u'_id': u'Setor Serra Dourada - 2\xaa Etapa', u'count': 17}
# None
# {u'_id': u'Conjunto Fabiana', u'count': 16}
# None
# {u'_id': u'Terra Prometida', u'count': 16}
# None
# {u'_id': u'Parque Atalaia', u'count': 15}
# None
# {u'_id': u'Jardim Esplanada', u'count': 14}
# None
# {u'_id': u'Parque Floresta', u'count': 14}
# None
# {u'_id': u'Jardim Cristalino', u'count': 13}
# None
# {u'_id': u'Jardim Para\xedso', u'count': 13}
# None
# {u'_id': u'Conjunto Residencial Storil', u'count': 12}
# None
# {u'_id': u'Jardim Novo Mundo', u'count': 12}
# None
# {u'_id': u'Parque Itatiaia', u'count': 12}
# None
# {u'_id': u'Conjunto Habitacional Madre Germana - 2\xaa Etapa', u'count': 12}
# None
# {u'_id': u'Vila Santos Dumont', u'count': 11}
# None
# {u'_id': u'Jardim Guanabara', u'count': 11}
# None
# {u'_id': u'Residencial Alvaluz', u'count': 11}
# None
# {u'_id': u'Residencial Andrade Reis', u'count': 11}
# None
# {u'_id': u'Setor dos Estados', u'count': 10}
# None
# {u'_id': u'Jardim Rio Grande', u'count': 10}
# None
# {u'_id': u'Residencial Brasicon I', u'count': 10}
# None
# {u'_id': u'Setor Serra Dourada - 1\xaa Etapa', u'count': 10}
# None
# {u'_id': u'Quinta da Boa Vista', u'count': 10}
# None
# {u'_id': u'Vila Bras\xedlia', u'count': 10}
# None
# {u'_id': u'Jardim Ipiranga - Continua\xe7\xe3o', u'count': 9}
# None
# {u'_id': u'Riviera Sul', u'count': 9}
# None
# {u'_id': u'Setor Comendador Walmor', u'count': 9}
# None
# {u'_id': u'Jardim Ipiranga', u'count': 9}
# None
# {u'_id': u'Jardim Europa', u'count': 8}
# None
# {u'_id': u'Negr\xe3o de Lima', u'count': 8}
# None
# {u'_id': u'Cidade Vera Cruz', u'count': 8}
# None
# {u'_id': u'Residencial Maria Luiza', u'count': 7}
# None
# {u'_id': u'Vila Sul', u'count': 7}
# None
# {u'_id': u'Residencial Anhambi', u'count': 7}
# None
# {u'_id': u'Jardim Rio Dourado', u'count': 7}
# None
# {u'_id': u'Vila Conc\xf3rdia', u'count': 7}
# None
# {u'_id': u'Setor Bela Vista', u'count': 6}
# None
# {u'_id': u'Parque Ibirapuera', u'count': 6}
# None
# {u'_id': u'Colinas de Homero', u'count': 6}
# None
# {u'_id': u'Residencial S\xe3o Domingos', u'count': 6}
# None
# {u'_id': u'Grande Retiro', u'count': 6}
# None
# {u'_id': u'Setor Ana Rosa', u'count': 6}
# None
# {u'_id': u'Jardim Isaura', u'count': 6}
# None
# {u'_id': u'Setor Sul', u'count': 6}
# None
# {u'_id': u'P\xf3lo Empresarial Goi\xe1', u'count': 5}
# None
# {u'_id': u'Jd. Goi\xe1s', u'count': 5}
# None
# {u'_id': u'Santa Genoveva', u'count': 5}
# None
# {u'_id': u'Jardim Iracema', u'count': 4}
# None
# {u'_id': u'Granjas Reunidas Nossa Senhora de Lourdes', u'count': 4}
# None
# {u'_id': u'Jardim Curitiba', u'count': 4}
# None
# {u'_id': u'Jardim Canad\xe1', u'count': 4}
# None
# {u'_id': u'Marista', u'count': 4}
# None
# {u'_id': u'Osvaldo Rosa', u'count': 4}
# None
# {u'_id': u'Vila Mau\xe1', u'count': 4}
# None
# {u'_id': u'Setor Oeste', u'count': 4}
# None
# {u'_id': u'Cidade Sat\xe9lite S\xe3o Luiz', u'count': 4}
# None
# {u'_id': u'Setor Negr\xe3o de Lima', u'count': 3}
# None
# {u'_id': u'Vila Floren\xe7a', u'count': 3}
# None
# {u'_id': u'\xc1guas Claras', u'count': 3}
# None
# {u'_id': u'S\xcdTIOS SANTA LUZIA', u'count': 3}
# None
# {u'_id': u'St. Leste Universit\xe1rio', u'count': 3}
# None
# {u'_id': u'Setor Campinas', u'count': 3}
# None
# {u'_id': u'Residencial Aldeia do Vale', u'count': 3}
# None
# {u'_id': u'Setor Estrela Dalva', u'count': 3}
# None
# {u'_id': u'Setor Norte Ferrovi\xe1rio', u'count': 3}
# None
# {u'_id': u'Setor Aeroporto', u'count': 3}
# None
# {u'_id': u'Setor Bueno', u'count': 3}
# None
# {u'_id': u'Conjunto Cai\xe7ara', u'count': 3}
# None
# {u'_id': u'Vera Cruz II', u'count': 3}
# None
# {u'_id': u'Jardim Guanabara II', u'count': 3}
# None
# {u'_id': u'Setor Samarah', u'count': 3}
# None
# {u'_id': u'Garavelo Residencial Park', u'count': 3}
# None
# {u'_id': u'Goiania II', u'count': 2}
# None
# {u'_id': u'Jardim Dom Fernando II', u'count': 2}
# None
# {u'_id': u'Jardim Tiradentes;Residencial Anhambi', u'count': 2}
# None
# {u'_id': u'Solar das Candeias', u'count': 2}
# None
# {u'_id': u'Expansul Complemento', u'count': 2}
# None
# {u'_id': u'Bela Morada', u'count': 2}
# None
# {u'_id': u'Jardim Santo Ant\xf4nio', u'count': 2}
# None
# {u'_id': u'Vila Abaj\xe1', u'count': 2}
# None
# {u'_id': u'Veiga Jardim', u'count': 2}
# None
# {u'_id': u'Vila Santos Dumount', u'count': 2}
# None
# {u'_id': u'JARDIM AMERICA', u'count': 2}
# None
# {u'_id': u'Bairro Feliz', u'count': 2}
# None
# {u'_id': u'Aerovi\xe1rio', u'count': 2}
# None
# {u'_id': u'Vila Jo\xe3o Braz', u'count': 2}
# None
# {u'_id': u'Jardim Vila Boa', u'count': 2}
# None
# {u'_id': u'Setor Marista', u'count': 2}
# None
# {u'_id': u'Vila dos Alpes', u'count': 2}
# None
# {u'_id': u'Parque Tremend\xe3o', u'count': 2}
# None
# {u'_id': u'Setor Pedro Ludovico', u'count': 2}
# None
# {u'_id': u'Jardim Guanabara III', u'count': 2}
# None
# {u'_id': u'Jardim das Ac\xe1cias', u'count': 2}
# None
# {u'_id': u'Setor Noroeste', u'count': 2}
# None
# {u'_id': u'CENTRO', u'count': 2}
# None
# {u'_id': u'Bela Vista', u'count': 2}
# None
# {u'_id': u'Jardim Dom Bosco - 2\xaa Etapa', u'count': 2}
# None
# {u'_id': u'Pedro Ludovico', u'count': 2}
# None
# {u'_id': u'Progresso', u'count': 2}
# None
# {u'_id': u'Nova Su\xed\xe7a', u'count': 2}
# None
# {u'_id': u'Jardim Nova Esperan\xe7a', u'count': 1}
# None
# {u'_id': u'Ipiranga', u'count': 1}
# None
# {u'_id': u'Setor Marab\xe1', u'count': 1}
# None
# {u'_id': u'Jardim Miramar', u'count': 1}
# None
# {u'_id': u'Campus Universit\xe1rio', u'count': 1}
# None
# {u'_id': u'Setor Leste Vila Nova', u'count': 1}
# None
# {u'_id': u'Itatiaia', u'count': 1}
# None
# {u'_id': u'Itapu\xe3', u'count': 1}
# None
# {u'_id': u'S\xc3O DOMINGOS', u'count': 1}
# None
# {u'_id': u'Setor Fai\xe7alville', u'count': 1}
# None
# {u'_id': u'Residencial Solar Ville', u'count': 1}
# None
# {u'_id': u'Residencial Brisas do Cerrado', u'count': 1}
# None
# {u'_id': u'Veiga Jardim - Acr\xe9scimo', u'count': 1}
# None
# {u'_id': u'Parque Amaz\xf4nia', u'count': 1}
# None
# {u'_id': u'Vila Nossa Senhora Aparecida', u'count': 1}
# None
# {u'_id': u'Santa Genoveva 2', u'count': 1}
# None
# {u'_id': u'Vila Sull', u'count': 1}
# None
# {u'_id': u'Vila Campus II', u'count': 1}
# None
# {u'_id': u'Jardim Para\xedso I', u'count': 1}
# None
# {u'_id': u'Vila Itatiaia', u'count': 1}
# None
# {u'_id': u'RESIDENCIAL S\xc3O DOMINGOS', u'count': 1}
# None
# {u'_id': u'Jardim Tropical', u'count': 1}
# None
# {u'_id': u'VILA CONC\xd3RDIA', u'count': 1}
# None
# {u'_id': u'S\xe3o Domingos', u'count': 1}
# None
# {u'_id': u'Parque Veiga Jadim', u'count': 1}
# None
# {u'_id': u'Setor Urias Magalh\xe3es', u'count': 1}
# None
# {u'_id': u'Setor Morada do Sol', u'count': 1}
# None
# {u'_id': u'Residencial Cara\xedbas', u'count': 1}
# None
# {u'_id': u'Vila Nova', u'count': 1}
# None
# {u'_id': u'Goi\xe2nia 2', u'count': 1}
# None
# {u'_id': u'Morrada dos P\xe1ssaros', u'count': 1}
# None
# {u'_id': u'Resid\xeancial Portinari', u'count': 1}
# None
# {u'_id': u'Setor Rio Vermelho', u'count': 1}
# None
# {u'_id': u'setor norte ferrovi\xe1rio', u'count': 1}
# None
# {u'_id': u'Leste Universit\xe1rio', u'count': 1}
# None
# {u'_id': u'Retiro do Bosque - Acr\xe9scimo', u'count': 1}
# None
# {u'_id': u'Jardim Planalto', u'count': 1}
# None
# {u'_id': u'SETOR CENTRAL', u'count': 1}
# None
# {u'_id': u'Jardim Olimpico', u'count': 1}
# None
# {u'_id': u'Setor Cora Coralina', u'count': 1}
# None
# {u'_id': u'Jardim Gauanabara', u'count': 1}
# None
# {u'_id': u'Setor Ja\xf3', u'count': 1}
# None
# {u'_id': u'Jardim Ipanema Complemento', u'count': 1}
# None
# {u'_id': u'Jardim Pomp\xe9ia', u'count': 1}
# None
# {u'_id': u'setor sul', u'count': 1}
# None
# {u'_id': u'Vila Lucy', u'count': 1}
# None
# {u'_id': u'Parque Santa Cruz', u'count': 1}
# None
# {u'_id': u'Setor Nova Sui\xe7a', u'count': 1}
# None
# {u'_id': u'Mans\xf5es do Campus', u'count': 1}
# None
# {u'_id': u'Parque Atheneu', u'count': 1}
# None
# {u'_id': u'Conjunto Vera Cruz', u'count': 1}
# None
# {u'_id': u'Jardim Decolores', u'count': 1}
# None
# {u'_id': u'Conjunto Vera Cruz II', u'count': 1}
# None
# {u'_id': u'Vila Adilair', u'count': 1}
# None
# {u'_id': u'Jardim Petr\xf3polis', u'count': 1}
# None
# {u'_id': u'Jardim Para\xedso Acr\xe9scimo', u'count': 1}
# None
# {u'_id': u'Jardim Imperial', u'count': 1}
# None
# {u'_id': u'Setor dos Afonsos', u'count': 1}
# None
# {u'_id': u'Jd Am\xe9rica', u'count': 1}
# None
# {u'_id': u'Vila jaragu\xe1', u'count': 1}
# None
# {u'_id': u'Setor Coimbra', u'count': 1}
# None
# {u'_id': u'Parque Industrial Araguaia', u'count': 1}
# None
# {u'_id': u'Vila Maria Dilce', u'count': 1}
# None
# {u'_id': u'Bairro S\xe3o Francisco', u'count': 1}
# None
# {u'_id': u'Setor dos Funcion\xe1rios', u'count': 1}
# None
# {u'_id': u'Centro Oeste', u'count': 1}
# None
# {u'_id': u'Nova Vila', u'count': 1}
# None
# {u'_id': u'SETOR MARISTA', u'count': 1}
# None
# {u'_id': u'St. alto do vale', u'count': 1}
# None
# {u'_id': u'Vila Delfiore', u'count': 1}
# None
# {u'_id': u'Residencial Vieira', u'count': 1}
# None
# {u'_id': u'Setor Crim\xe9ia Leste', u'count': 1}
# None
# {u'_id': u'All Park Polo Empresarial', u'count': 1}
# None
# {u'_id': u'Universit\xe1rio', u'count': 1}
# None

# %%
#amenity: restaurant cousine
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'place_of_worship'}}).distinct("caract.religion")
#most frequent cuisine 
query = []
query.append({"$match":{"caract.amenity":{"$exists": True, "$eq": u'place_of_worship'}}})
query.append({"$group" : {"_id" : "$caract.religion", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
religion = db.goiania.aggregate(query)
for doc in religion:
    print pprint.pprint(doc)
# Out:
# [u'christian', u'Spiritist']
# {u'_id': u'christian', u'count': 66}
# None
# {u'_id': None, u'count': 21}
# None
# {u'_id': u'Spiritist', u'count': 1}
# None

# %%
#information about the most common amenity parking

parking = db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'parking'}})
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'parking'}}).count()
print db.goiania.find({"$and" : [{"caract.amenity":{"$exists": True, "$eq": u'parking'}}, {"addr":{"$exists": True}}]}).count()


#for doc in parking:
 #   print pprint.pprint(doc)
# Out:
# 165
# 3

# %%
#information about quantity of addr in the amenities restaurant
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'restaurant'}}).count()
print db.goiania.find({"$and" : [{"caract.amenity":{"$exists": True, "$eq": u'restaurant'}}, {"addr":{"$exists": True}}]}).count()
# Out:
# 78
# 14

# %%
#information about quantity of addr in the amenities fuel
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'fuel'}}).count()
print db.goiania.find({"$and" : [{"caract.amenity":{"$exists": True, "$eq": u'fuel'}}, {"addr":{"$exists": True}}]}).count()
# Out:
# 160
# 12

# %%
#information about quantity of addr in the amenities bank
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'bank'}}).count()
print db.goiania.find({"$and" : [{"caract.amenity":{"$exists": True, "$eq": u'bank'}}, {"addr":{"$exists": True}}]}).count()
# Out:
# 112
# 11

# %%
#information about the second most common amenity fuel

fuel = db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'fuel'}})
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'fuel'}}).distinct("caract.brand")


#for doc in parking:
 #   print pprint.pprint(doc)
# Out:
# [u'BP', u'Rede 3', u'Ale', u'BR', u'Texaco', u'Shell', u'ALE', u'Z+Z', u'Petrobras', u'shell', u'XPETRO', u'bridgestone', u'Petrobr\xe1s']

# %%
#information about school
school = db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'school'}})

for doc in school:
    print pprint.pprint(doc)
# Out:
# {u'_id': ObjectId('5ac0e4b7659c2a221c56e121'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'9904590',
#               u'timestamp': u'2011-11-22T03:51:02Z',
#               u'uid': u'149876',
#               u'user': u'dbusse',
#               u'version': u'3'},
#  u'id': u'588236790',
#  u'pos': [-16.7134662, -49.2569001],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b7659c2a221c579180'),
#  u'caract': {u'amenity': u'school', u'name': u'FACLIONS - Faculdade Lions'},
#  u'created': {u'changeset': u'11666712',
#               u'timestamp': u'2012-05-21T21:37:00Z',
#               u'uid': u'686556',
#               u'user': u'danilokbrito',
#               u'version': u'1'},
#  u'id': u'1761563606',
#  u'pos': [-16.60819, -49.2015289],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e

#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b8659c2a221c57e2e6'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Castro Alves'},
#  u'created': {u'changeset': u'19621463',
#               u'timestamp': u'2013-12-24T18:35:40Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'2593029297',
#  u'pos': [-16.6560123, -49.2808906],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b8659c2a221c57e6f7'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Planeta'},
#  u'created': {u'changeset': u'19633847',
#               u'timestamp': u'2013-12-25T19:16:12Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'2594280397',
#  u'pos': [-16.6600456, -49.2598781],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b8659c2a221c57e6f8'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio da Pol\xedcia Militar de Goi\xe1s - Hugo de Carvalho Ramos'},
#  u'created': {u'changeset': u'19633847',
#               u'timestamp': u'2013-12-25T19:16:12Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'2594280398',
#  u'pos': [-16.6997037, -49.2428931],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b8659c2a221c57e6fe'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Internacional de Goi\xe2nia'},
#  u'created': {u'changeset': u'19633847',
#               u'timestamp': u'2013-12-25T19:16:12Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'2594280404',
#  u'pos': [-16.6952162, -49.2661456],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c5967b3'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'26418505',
#               u'timestamp': u'2014-10-29T18:15:06Z',
#               u'uid': u'2431961',
#               u'user': u'Fabricio Moura',
#               u'version': u'1'},
#  u'id': u'3156572089',
#  u'pos': [-16.661122, -49.3852294],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d923'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'street': u'R. GB 19',
#            u'suburb': u'Jardim Guanabara II'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Mun. Prof. Louren\xe7o Ferreira',
#              u'source': u'Prefeitura de Goi\xe2nia http://www.goiania.go.gov.br'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602106',
#  u'pos': [-16.6121459, -49.2141963],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d924'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Est. Jornalista Contart',
#              u'source': u'Prefeitura de Goi\xe2nia http://www.goiania.go.gov.br'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602107',
#  u'pos': [-16.6131936, -49.2147946],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d925'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Mun. Mar\xedlia Carneiro',
#              u'source': u'Prefeitura de Goi\xe2nia http://www.goiania.go.gov.br'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602108',
#  u'pos': [-16.6120524, -49.2182493],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d927'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Mun. Padre Pel\xe1gio',
#              u'source': u'Prefeitura de Goi\xe2nia http://www.goiania.go.gov.br'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602110',
#  u'pos': [-16.6138104, -49.2210066],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d92a'),
#  u'caract': {u'amenity': u'school', u'name': u'Escola Prof. Yolanda'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602113',
#  u'pos': [-16.6173313, -49.2206577],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59d92b'),
#  u'caract': {u'amenity': u'school',
#              u'source': u'Prefeitura de Goi\xe2nia http://www.goiania.go.gov.br'},
#  u'created': {u'changeset': u'27614675',
#               u'timestamp': u'2014-12-21T18:08:44Z',
#               u'uid': u'2531875',
#               u'user': u'danhcs',
#               u'version': u'1'},
#  u'id': u'3246602114',
#  u'pos': [-16.6170989, -49.2170551],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59e07e'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Am\xe9lia Fernandes Martins'},
#  u'created': {u'changeset': u'29035524',
#               u'timestamp': u'2015-02-23T03:43:44Z',
#               u'uid': u'2691244',
#               u'user': u'RCRibeiro22',
#               u'version': u'1'},
#  u'id': u'3367362640',
#  u'pos': [-16.7328623, -49.2285254],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59e0ff'),
#  u'caract': {u'amenity': u'school', u'name': u'Instituto San Damiano'},
#  u'created': {u'changeset': u'29414015',
#               u'timestamp': u'2015-03-11T20:33:17Z',
#               u'uid': u'2691244',
#               u'user': u'RCRibeiro22',
#               u'version': u'1'},
#  u'id': u'3394417062',
#  u'pos': [-16.7500358, -49.2036563],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59e100'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Major Oscar Alvelos'},
#  u'created': {u'changeset': u'29414015',
#               u'timestamp': u'2015-03-11T20:33:17Z',
#               u'uid': u'2691244',
#               u'user': u'RCRibeiro22',
#               u'version': u'1'},
#  u'id': u'3394417063',
#  u'pos': [-16.7513868, -49.2004376],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4b9659c2a221c59e263'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Menino Jesus'},
#  u'created': {u'changeset': u'29858780',
#               u'timestamp': u'2015-03-30T19:03:21Z',
#               u'uid': u'2691244',
#               u'user': u'RCRibeiro22',
#               u'version': u'1'},
#  u'id': u'3427336299',
#  u'pos': [-16.7299098, -49.2285456],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e

#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a563e'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'CMEI Mateus Barcelos Barretos.'},
#  u'created': {u'changeset': u'44798909',
#               u'timestamp': u'2016-12-31T02:25:28Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'4582168809',
#  u'pos': [-16.7297872, -49.3180682],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a563f'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Faculdade Padr\xe3o',
#              u'operator': u'Campus Novo Horizonte'},
#  u'created': {u'changeset': u'44991855',
#               u'timestamp': u'2017-01-08T00:59:52Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'2'},
#  u'id': u'4582170084',
#  u'pos': [-16.726149, -49.3200974],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a5671'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Jardim Vila Boa'},
#  u'created': {u'changeset': u'44822572',
#               u'timestamp': u'2017-01-01T13:29:47Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'4583831572',
#  u'pos': [-16.7308053, -49.3216553],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a5672'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Deputado Jamel Cec\xedlio'},
#  u'created': {u'changeset': u'44823086',
#               u'timestamp': u'2017-01-01T13:59:52Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'2'},
#  u'id': u'4583831573',
#  u'pos': [-16.7309765, -49.3225211],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a5679'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Novo Horizonte'},
#  u'created': {u'changeset': u'44823389',
#               u'timestamp': u'2017-01-01T14:15:46Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'4583871850',
#  u'pos': [-16.713951, -49.3181776],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a77bb'),
#  u'caract': {u'amenity': u'school', u'name': u'UNI-ANHANGUERA'},
#  u'created': {u'changeset': u'45602112',
#               u'timestamp': u'2017-01-28T19:32:41Z',
#               u'uid': u'5061841',
#               u'user': u'Cristianocesarino',
#               u'version': u'1'},
#  u'id': u'4640409394',
#  u'name': {u'pt': u'UNI-ANHANGUERA'},
#  u'pos': [-16.6915841, -49.3142174],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a8b7a'),
#  u'addr': {u'city': u'Aparecida de Goi\xe2nia',
#            u'street': u'Avenida W 2',
#            u'suburb': u'Mans\xf5es Para\xedso'},
#  u'caract': {u'amenity': u'school', u'name': u'Escola Estadual Elmar Arantes'},
#  u'created': {u'changeset': u'46665763',
#               u'timestamp': u'2017-03-07T22:48:14Z',
#               u'uid': u'4315698',
#               u'user': u'Marckos Reis',
#               u'version': u'1'},
#  u'id': u'4723233613',
#  u'pos': [-16.777339, -49.2821514],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5a900c'),
#  u'caract': {u'amenity': u'school', u'name': u'Minds'},
#  u'created': {u'changeset': u'46985920',
#               u'timestamp': u'2017-03-19T15:44:30Z',
#               u'uid': u'360183',
#               u'user': u'wille',
#               u'version': u'2'},
#  u'id': u'4741778124',
#  u'name': {u'pt': u'Minds'},
#  u'pos': [-16.6874609, -49.2669581],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5aaa2a'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Instituto Federal de Goi\xe1s - Goi\xe2nia (IFG)'},
#  u'created': {u'changeset': u'50923066',
#               u'timestamp': u'2017-08-07T17:01:31Z',
#               u'uid': u'6425695',
#               u'user': u'fabricio sp',
#               u'version': u'2'},
#  u'id': u'4972519025',
#  u'pos': [-16.6658129, -49.2549844],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5aaa2c'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Santo Agostinnho'},
#  u'created': {u'changeset': u'50923066',
#               u'timestamp': u'2017-08-07T17:01:31Z',
#               u'uid': u'6425695',
#               u'user': u'fabricio sp',
#               u'version': u'2'},
#  u'id': u'4972519029',
#  u'pos': [-16.667324, -49.255304],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5abb2d'),
#  u'addr': {u'street': u'Rua RI 9'},
#  u'caract': {u'amenity': u'school',
#              u'email': u'colegiostillo@gmail.com',
#              u'name': u'Col\xe9gio Stillo',
#              u'opening_hours': u'Mo-Fr 07:00-18:00',
#              u'phone': u'35786929'},
#  u'created': {u'changeset': u'53737118',
#               u'timestamp': u'2017-11-13T11:11:54Z',
#               u'uid': u'6978704',
#               u'user': u'Hitler Lynce Caetano',
#               u'version': u'1'},
#  u'id': u'5226264621',
#  u'pos': [-16.793549, -49.373799],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5acf41'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Professora Dal\xedsia Elisabeth Martins Doles'},
#  u'created': {u'changeset': u'54338558',
#               u'timestamp': u'2017-12-04T18:36:18Z',
#               u'uid': u'7149222',
#               u'user': u'dearaujojr',
#               u'version': u'1'},
#  u'id': u'5264242751',
#  u'pos': [-16.6222521, -49.2523772],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5acfd9'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'housenumber': u'489',
#            u'postcode': u'74633-140',
#            u'street': u'Rua 6',
#            u'suburb': u'Osvaldo Rosa'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Simetria',
#              u'website': u'colegiosimetria.com.br'},
#  u'created': {u'changeset': u'54351326',
#               u'timestamp': u'2017-12-05T02:29:05Z',
#               u'uid': u'7152578',
#               u'user': u'Kayofp',
#               u'version': u'1'},
#  u'id': u'5264994326',
#  u'pos': [-16.6668078, -49.232753],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5ae8c7'),
#  u'caract': {u'amenity': u'school', u'name': u'Escola Interamerica'},
#  u'created': {u'changeset': u'56636712',
#               u'timestamp': u'2018-02-24T13:51:20Z',
#               u'uid': u'6508483',
#               u'user': u'Nor@Nor',
#               u'version': u'1'},
#  u'id': u'5433395821',
#  u'pos': [-16.709959, -49.2766119],
#  u'type': u'node'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b1c11'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Benedita Luiza da Silva Miranda'},
#  u'created': {u'changeset': u'20623446',
#               u'timestamp': u'2014-02-17T20:29:22Z',
#               u'uid': u'463504',
#               u'user': u'erickdeoliveiraleal',
#               u'version': u'2'},
#  u'id': u'220822255',
#  u'node_refs': [u'2299091112',
#                 u'2299091111',
#                 u'2299091110',
#                 u'2299091108',
#                 u'2299091102',
#                 u'2299091099',
#                 u'2299091097',
#                 u'2299091104',
#                 u'2299091107',
#                 u'2299091112'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b240b'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Itamar Martins Ferreira',
#              u'operator': u'Prefeitura de Goi\xe2nia'},
#  u'created': {u'changeset': u'19574939',
#               u'timestamp': u'2013-12-22T00:08:58Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'252981107',
#  u'node_refs': [u'2589797037',
#                 u'2589797034',
#                 u'2589797026',
#                 u'2589797019',
#                 u'2589797020',
#                 u'2589797022',
#                 u'2589797027',
#                 u'2589797036',
#                 u'2589797038',
#                 u'2589797037'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b2416'),
#  u'caract': {u'alt_name': u'Jeca',
#              u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Professor Jo\u015be Carlos de Almeida',
#              u'operator': u'Governo de Goi\xe1s'},
#  u'created': {u'changeset': u'19575072',
#               u'timestamp': u'2013-12-22T00:27:01Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'252981914',
#  u'node_refs': [u'2589802604',
#                 u'2589802602',
#                 u'2589802586',
#                 u'2589802580',
#                 u'2589802574',
#                 u'2589802576',
#                 u'2589802600',
#                 u'2589802604'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b2417'),
#  u'caract': {u'amenity': u'school', u'name': u'Lyceu de Goi\xe2nia'},
#  u'created': {u'changeset': u'19575072',
#               u'timestamp': u'2013-12-22T00:27:01Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'252981915',
#  u'node_refs': [u'2589802571',
#                 u'2589802570',
#                 u'2589802563',
#                 u'2589802562',
#                 u'2589802565',
#                 u'2589802567',
#                 u'2589802568',
#                 u'2589802569',
#                 u'2589802572',
#                 u'2589802573',
#                 u'2589802571'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b24e6'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Joana Ang\xe9lica Rissaris Paganin'},
#  u'created': {u'changeset': u'19628815',
#               u'timestamp': u'2013-12-25T12:21:27Z',
#               u'uid': u'1713440',
#               u'user': u'taciofernandes',
#               u'version': u'1'},
#  u'id': u'253456431',
#  u'node_refs': [u'2593807308',
#                 u'2593807309',
#                 u'2593807299',
#                 u'2593807292',
#                 u'2593807279',
#                 u'2593807278',
#                 u'2593807285',
#                 u'2593807288',
#                 u'2593807308'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b2582'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola de Artes Veiga Valle e Centro de Educa\xe7\xe3o Profissional em Artes Basileu Fran\xe7a'},
#  u'created': {u'changeset': u'21595979',
#               u'timestamp': u'2014-04-09T20:16:02Z',
#               u'uid': u'463507',
#               u'user': u'naoliv',
#               u'version': u'2'},
#  u'id': u'256929001',
#  u'node_refs': [u'2625491707',
#                 u'2625491708',
#                 u'2625491709',
#                 u'2625491710',
#                 u'2625491711',
#                 u'2625491707'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b263c'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Balne\xe1rio M. Ponte'},
#  u'created': {u'changeset': u'35915074',
#               u'timestamp': u'2015-12-12T19:37:27Z',
#               u'uid': u'463504',
#               u'user': u'erickdeoliveiraleal',
#               u'version': u'4'},
#  u'id': u'259057091',
#  u'node_refs': [u'2643878166',
#                 u'3062694035',
#                 u'3062694054',
#                 u'2643878168',
#                 u'2643878169',
#                 u'2643878172',
#                 u'2643878174',
#                 u'2643878177',
#                 u'2643878181',
#                 u'2643878166'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b263e'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Hebert Jos\xe9 de Souza'},
#  u'created': {u'changeset': u'25264084',
#               u'timestamp': u'2014-09-06T10:19:24Z',
#               u'uid': u'1352904',
#               u'user': u'street0501',
#               u'version': u'2'},
#  u'id': u'259057094',
#  u'node_refs': [u'2643878193',
#                 u'3062718122',
#                 u'2643878196',
#                 u'3062718119',
#                 u'2643878197',
#                 u'2643878193'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b2678'),
#  u'caract': {u'amenity': u'school',
#              u'building': u'school',
#              u'name': u'Escola \xc1pice'},
#  u'created': {u'changeset': u'22814660',
#               u'timestamp': u'2014-06-08T17:54:51Z',
#               u'uid': u'463504',
#               u'user': u'erickdeoliveiraleal',
#               u'version': u'2'},
#  u'id': u'265204891',
#  u'node_refs': [u'2708669673',
#                 u'2708669674',
#                 u'2708669675',
#                 u'2708669676',
#                 u'2708669673'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b2692'),
#  u'caract': {u'amenity': u'school', u'name': u'Escola Municipal Cara\xedbas'},
#  u'created': {u'changeset': u'22113462',
#               u'timestamp': u'2014-05-03T20:12:09Z',
#               u'uid': u'1802503',
#               u'user': u'framap',
#               u'version': u'2'},
#  u'id': u'273804622',
#  u'node_refs': [u'2786197212',
#                 u'2786197207',
#                 u'2786197215',
#                 u'2786197218',
#                 u'2786197222',
#                 u'2786197228',
#                 u'2786197232',
#                 u'2786197225',
#                 u'2786197212'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b33b4'),
#  u'caract': {u'amenity': u'school', u'name': u'Escola'},
#  u'created': {u'changeset': u'24401843',
#               u'timestamp': u'2014-07-28T13:08:43Z',
#               u'uid': u'2056863',
#               u'user': u'jdaraujo',
#               u'version': u'1'},
#  u'id': u'294820635',
#  u'node_refs': [u'2984427388',
#                 u'2984427885',
#                 u'2984427886',
#                 u'2984427887',
#                 u'2984427389',
#                 u'2984427388'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b47c0'),
#  u'caract': {u'amenity': u'school', u'name': u'CMEI Cantinho Feliz'},
#  u'created': {u'changeset': u'25250729',
#               u'timestamp': u'2014-09-05T15:20:26Z',
#               u'uid': u'1352904',
#               u'user': u'street0501',
#               u'version': u'1'},
#  u'id': u'301936460',
#  u'node_refs': [u'2593029295',
#                 u'3061103626',
#                 u'3061103622',
#                 u'3061103623',
#                 u'2593029295'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b7907'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Alice Coutinho'},
#  u'created': {u'changeset': u'29279656',
#               u'timestamp': u'2015-03-05T23:58:06Z',
#               u'uid': u'1310899',
#               u'user': u'Linhares',
#               u'version': u'1'},
#  u'id': u'331461677',
#  u'node_refs': [u'3385375927',
#                 u'3385375930',
#                 u'3385375932',
#                 u'3385375931',
#                 u'3385375933',
#                 u'3385375929',
#                 u'3385375928',
#                 u'3385375926',
#                 u'3385375927'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b7fa2'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'32997710',
#               u'timestamp': u'2015-07-31T03:25:58Z',
#               u'uid': u'463504',
#               u'user': u'erickdeoliveiraleal',
#               u'version': u'2'},
#  u'id': u'361069439',
#  u'node_refs': [u'3655915891',
#                 u'3655915892',
#                 u'1721202571',
#                 u'3655915894',
#                 u'3655915895',
#                 u'3655915896',
#                 u'3655915891'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b804e'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Pr\xe9-Universit\xe1rio'},
#  u'created': {u'changeset': u'35915074',
#               u'timestamp': u'2015-12-12T19:37:27Z',
#               u'uid': u'463504',
#               u'user': u'erickdeoliveiraleal',
#               u'version': u'2'},
#  u'id': u'362306220',
#  u'node_refs': [u'3666374936',
#                 u'3666374937',
#                 u'3666374938',
#                 u'3666374939',
#                 u'3666374940',
#                 u'3666374941',
#                 u'3666374942',
#                 u'3666374943',
#                 u'3666374944',
#                 u'3666374946',
#                 u'3666374936'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b8229'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'street': u'Rua R-034',
#            u'suburb': u'Itatiaia'},
#  u'caract': {u'amenity': u'school',
#              u'building': u'school',
#              u'name': u'Escola Municipal Brice Francisco Cordeiro',
#              u'phone': u'+55 62 35248952'},
#  u'created': {u'changeset': u'37480510',
#               u'timestamp': u'2016-02-27T12:44:14Z',
#               u'uid': u'2041027',
#               u'user': u'jeffersonbr',
#               u'version': u'2'},
#  u'id': u'370258145',
#  u'node_refs': [u'3739714965',
#                 u'3739714966',
#                 u'3739714967',
#                 u'3739714968',
#                 u'3739714965'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b822a'),
#  u'addr': {u'street': u'Rua r-040'},
#  u'caract': {u'amenity': u'school',
#              u'building': u'school',
#              u'name': u'Col\xe9gio Estadual Waldemar Mundim'},
#  u'created': {u'changeset': u'37480510',
#               u'timestamp': u'2016-02-27T12:44:14Z',
#               u'uid': u'2041027',
#               u'user': u'jeffersonbr',
#               u'version': u'2'},
#  u'id': u'370258469',
#  u'node_refs': [u'3739717809',
#                 u'3739717810',
#                 u'3739717811',
#                 u'3739717812',
#                 u'3739717809'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b8574'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'35289592',
#               u'timestamp': u'2015-11-13T17:49:15Z',
#               u'uid': u'2647840',
#               u'user': u'geocorreiosgo',
#               u'version': u'1'},
#  u'id': u'380113662',
#  u'node_refs': [u'3834623703',
#                 u'3834623704',
#                 u'3834623705',
#                 u'3834623706',
#                 u'3834623703'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b85dd'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'35352840',
#               u'timestamp': u'2015-11-16T14:56:51Z',
#               u'uid': u'2647840',
#               u'user': u'geocorreiosgo',
#               u'version': u'1'},
#  u'id': u'380590882',
#  u'node_refs': [u'3839087645',
#                 u'3839087646',
#                 u'3839087647',
#                 u'3839087648',
#                 u'3839087649',
#                 u'3839087645'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b8609'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'ESCOLA MUNICIPAL PADRE CONRADO'},
#  u'created': {u'changeset': u'35414258',
#               u'timestamp': u'2015-11-18T18:11:45Z',
#               u'uid': u'2647840',
#               u'user': u'geocorreiosgo',
#               u'version': u'1'},
#  u'id': u'381032169',
#  u'node_refs': [u'3843132795',
#                 u'3843132796',
#                 u'3843132797',
#                 u'3843132798',
#                 u'3843132795'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4ba659c2a221c5b88ee'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Marista'},
#  u'created': {u'changeset': u'36749034',
#               u'timestamp': u'2016-01-22T21:49:30Z',
#               u'uid': u'463507',
#               u'user': u'naoliv',
#               u'version': u'2'},
#  u'id': u'392820669',
#  u'node_refs': [u'2526862583',
#                 u'3960155442',
#                 u'3960155443',
#                 u'3960155444',
#                 u'3960155445',
#                 u'3960155446',
#                 u'2526862583'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5b8c6d'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'postcode': u'74475-160',
#            u'street': u'Avenida Mangal\xf4',
#            u'suburb': u'Setor Morada do Sol'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Leon\xedsia Naves de Almeida',
#              u'operator': u'Prefeitura Municipal de Goi\xe2nia',
#              u'phone': u'+55 62 35172189'},
#  u'created': {u'changeset': u'45537467',
#               u'timestamp': u'2017-01-27T01:21:23Z',
#               u'uid': u'94659',
#               u'user': u'Andr\xe9 Alvarenga',
#               u'version': u'2'},
#  u'id': u'403177010',
#  u'node_refs': [u'4055531372',
#                 u'4055531373',
#                 u'4055531374',
#                 u'4055531375',
#                 u'4055531372'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5b8c7b'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola de Futebol do Atl\xe9tico Goianiense',
#              u'operator': u'Atl\xe9tico Clube Goianiense',
#              u'sport': u'soccer',
#              u'training': u'sport'},
#  u'created': {u'changeset': u'37774174',
#               u'timestamp': u'2016-03-11T22:29:09Z',
#               u'uid': u'2041027',
#               u'user': u'jeffersonbr',
#               u'version': u'1'},
#  u'id': u'403182169',
#  u'node_refs': [u'4055571785',
#                 u'4055571786',
#                 u'4055571787',
#                 u'4055571788',
#                 u'4055571785'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5b99d8'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'street': u'Rua 1',
#            u'suburb': u'Conjunto Fabiana'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Zevera Andrea Vecci'},
#  u'created': {u'changeset': u'44544787',
#               u'timestamp': u'2016-12-20T16:28:44Z',
#               u'uid': u'2647840',
#               u'user': u'geocorreiosgo',
#               u'version': u'1'},
#  u'id': u'460771918',
#  u'node_refs': [u'4563752774',
#                 u'4563752775',
#                 u'4563752776',
#                 u'4563752777',
#                 u'4563752778',
#                 u'4563752779',
#                 u'4563752774'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5b9fec'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Estadual Deputado Jos\xe9 Luciano'},
#  u'created': {u'changeset': u'45151744',
#               u'timestamp': u'2017-01-14T01:09:40Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'465795116',
#  u'node_refs': [u'4607144281',
#                 u'4607144282',
#                 u'4607144283',
#                 u'4607144284',
#                 u'4607144285',
#                 u'4607144286',
#                 u'4607144287',
#                 u'4607144288',
#                 u'4607144281'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba1a8'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'45456848',
#               u'timestamp': u'2017-01-25T01:42:28Z',
#               u'uid': u'5182350',
#               u'user': u'Adriano Xavier',
#               u'version': u'1'},
#  u'id': u'468581440',
#  u'node_refs': [u'4631006736',
#                 u'4631006737',
#                 u'4631006738',
#                 u'4631006739',
#                 u'4631006740',
#                 u'4631006741',
#                 u'4631006742',
#                 u'4631006743',
#                 u'4631006744',
#                 u'4631006736'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba1ee'),
#  u'addr': {u'street': u'Rua 260'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Dom Abel Su'},
#  u'created': {u'changeset': u'45481732',
#               u'timestamp': u'2017-01-25T16:41:55Z',
#               u'uid': u'5182350',
#               u'user': u'Adriano Xavier',
#               u'version': u'1'},
#  u'id': u'468774683',
#  u'node_refs': [u'4632428176',
#                 u'4632428177',
#                 u'4632428178',
#                 u'4632428179',
#                 u'4632428180',
#                 u'4632428181',
#                 u'4632428176'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba3c2'),
#  u'caract': {u'amenity': u'school', u'name': u'Meta J\xfanior'},
#  u'created': {u'changeset': u'46087387',
#               u'timestamp': u'2017-02-14T19:10:08Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'474665948',
#  u'node_refs': [u'4685705943',
#                 u'4685705944',
#                 u'4685705945',
#                 u'4685705946',
#                 u'4685705947',
#                 u'4685705948',
#                 u'4685705949',
#                 u'4685705943'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba3c6'),
#  u'caract': {u'amenity': u'school', u'name': u'Meta Brasil'},
#  u'created': {u'changeset': u'46087387',
#               u'timestamp': u'2017-02-14T19:10:09Z',
#               u'uid': u'5052207',
#               u'user': u'Dangoh',
#               u'version': u'1'},
#  u'id': u'474665952',
#  u'node_refs': [u'4685705969',
#                 u'4685705970',
#                 u'4685705971',
#                 u'4685705972',
#                 u'4685705973',
#                 u'4685705974',
#                 u'4685705975',
#                 u'4685705976',
#                 u'4685705977',
#                 u'4685705978',
#                 u'4685705969'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba419'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'46405371',
#               u'timestamp': u'2017-02-25T23:25:05Z',
#               u'uid': u'360183',
#               u'user': u'wille',
#               u'version': u'1'},
#  u'id': u'477203543',
#  u'node_refs': [u'4705926142',
#                 u'4705926143',
#                 u'4705926144',
#                 u'4705926145',
#                 u'4705926146',
#                 u'4705926147',
#                 u'4705926148',
#                 u'4705926149',
#                 u'4705926142'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba41f'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Cora Coralina'},
#  u'created': {u'changeset': u'46405371',
#               u'timestamp': u'2017-02-25T23:25:06Z',
#               u'uid': u'360183',
#               u'user': u'wille',
#               u'version': u'1'},
#  u'id': u'477203549',
#  u'node_refs': [u'4705926187',
#                 u'4705926188',
#                 u'4705927389',
#                 u'4705927390',
#                 u'4705927392',
#                 u'4705927391',
#                 u'4705926187'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba420'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'46405371',
#               u'timestamp': u'2017-02-25T23:25:06Z',
#               u'uid': u'360183',
#               u'user': u'wille',
#               u'version': u'1'},
#  u'id': u'477203550',
#  u'node_refs': [u'4705927393',
#                 u'4705927394',
#                 u'4705927395',
#                 u'4705927396',
#                 u'4705927397',
#                 u'4705927398',
#                 u'4705927399',
#                 u'4705927400',
#                 u'4705927401',
#                 u'4705927402',
#                 u'4705927393'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba58a'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'OSCEIA',
#              u'name_1': u'Obras Sociais do Centro Esp\xedrita Irm\xe3o \xc1ureo'},
#  u'created': {u'changeset': u'55280312',
#               u'timestamp': u'2018-01-09T02:19:12Z',
#               u'uid': u'6600842',
#               u'user': u'Danillo Parreira',
#               u'version': u'2'},
#  u'id': u'481641342',
#  u'node_refs': [u'4745531893',
#                 u'4745531894',
#                 u'4745531895',
#                 u'4745531896',
#                 u'4745531897',
#                 u'4745531898',
#                 u'4745531899',
#                 u'4745531900',
#                 u'4745531901',
#                 u'4745531902',
#                 u'4745531903',
#                 u'4745531893'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba785'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'PUC Idiomas',
#              u'operator': u'Pontif\xedcia Universidade Cat\xf3lica de Goi\xe1s',
#              u'website': u'http://sites.pucgoias.edu.br/puc/pucidiomas/'},
#  u'created': {u'changeset': u'48362513',
#               u'timestamp': u'2017-05-03T11:10:01Z',
#               u'uid': u'360183',
#               u'user': u'wille',
#               u'version': u'1'},
#  u'id': u'491105774',
#  u'node_refs': [u'4832592769',
#                 u'4832592770',
#                 u'4832592771',
#                 u'4832592772',
#                 u'4832592773',
#                 u'4832592769'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba894'),
#  u'addr': {u'city': u'Goi\xe2nia',
#            u'postcode': u'74690-900',
#            u'suburb': u'Campus Universit\xe1rio'},
#  u'caract': {u'amenity': u'school',
#              u'name': u'CEPAE/UFG - Centro de Ensino e Pesquisa Aplicados \xe0 Educa\xe7\xe3o',
#              u'phone': u'(62) 3521-1026',
#              u'website': u'https://www.cepae.ufg.br/'},
#  u'created': {u'changeset': u'48550044',
#               u'timestamp': u'2017-05-10T04:31:46Z',
#               u'uid': u'1206082',
#               u'user': u'T\xfallio',
#               u'version': u'1'},
#  u'id': u'492478555',
#  u'node_refs': [u'4844972968',
#                 u'4844972969',
#                 u'4844972970',
#                 u'4844972971',
#                 u'4844972972',
#                 u'4844972973',
#                 u'4844972974',
#                 u'4844972983',
#                 u'4844972975',
#                 u'4844972976',
#                 u'4844972977',
#                 u'4844972978',
#                 u'4844972982',
#                 u'4844972979',
#                 u'4844972980',
#                 u'4844972981',
#                 u'4844972968'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba93a'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Express\xe3o'},
#  u'created': {u'changeset': u'49955929',
#               u'timestamp': u'2017-06-30T23:19:17Z',
#               u'uid': u'6246167',
#               u'user': u'talesbeltrao',
#               u'version': u'1'},
#  u'id': u'504323407',
#  u'node_refs': [u'4944935921',
#                 u'4944935922',
#                 u'4944935923',
#                 u'4944935924',
#                 u'4944935921'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5ba9fd'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'50923066',
#               u'timestamp': u'2017-08-07T17:01:29Z',
#               u'uid': u'6425695',
#               u'user': u'fabricio sp',
#               u'version': u'1'},
#  u'id': u'513675760',
#  u'node_refs': [u'5020550669',
#                 u'5020550670',
#                 u'5020550671',
#                 u'5020550672',
#                 u'5020550673',
#                 u'5020550674',
#                 u'5020550675',
#                 u'5020550669'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5baecb'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Professora Dal\xedsia Elisabeth Martins Doles'},
#  u'created': {u'changeset': u'54338558',
#               u'timestamp': u'2017-12-04T18:36:18Z',
#               u'uid': u'7149222',
#               u'user': u'dearaujojr',
#               u'version': u'1'},
#  u'id': u'544599617',
#  u'node_refs': [u'3063902935',
#                 u'5264242748',
#                 u'5264242749',
#                 u'5264242750',
#                 u'3063902935'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb0ad'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Escola Municipal Jardim Nova Esperan\xe7a'},
#  u'created': {u'changeset': u'55277820',
#               u'timestamp': u'2018-01-08T22:48:33Z',
#               u'uid': u'6600842',
#               u'user': u'Danillo Parreira',
#               u'version': u'1'},
#  u'id': u'551739752',
#  u'node_refs': [u'5328188235',
#                 u'5328188243',
#                 u'5328188236',
#                 u'5328188237',
#                 u'5328188238',
#                 u'5328188239',
#                 u'5328188240',
#                 u'5328188241',
#                 u'5328188235'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb0ae'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'Col\xe9gio Estadual Robinho Martins de Azevedo'},
#  u'created': {u'changeset': u'55277820',
#               u'timestamp': u'2018-01-08T22:48:33Z',
#               u'uid': u'6600842',
#               u'user': u'Danillo Parreira',
#               u'version': u'1'},
#  u'id': u'551739753',
#  u'node_refs': [u'5328188242',
#                 u'5328188243',
#                 u'5328188236',
#                 u'5328188244',
#                 u'5328188245',
#                 u'5328188242'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb0af'),
#  u'caract': {u'amenity': u'school', u'name': u'Col\xe9gio Excelso'},
#  u'created': {u'changeset': u'55277820',
#               u'timestamp': u'2018-01-08T22:48:33Z',
#               u'uid': u'6600842',
#               u'user': u'Danillo Parreira',
#               u'version': u'1'},
#  u'id': u'551739754',
#  u'node_refs': [u'5328188246',
#                 u'5328188247',
#                 u'5328188248',
#                 u'5328188249',
#                 u'5328188246'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb0b0'),
#  u'caract': {u'amenity': u'school',
#              u'name': u'EM Coronel Jos\xe9 Viana Alves'},
#  u'created': {u'changeset': u'55277820',
#               u'timestamp': u'2018-01-08T22:48:33Z',
#               u'uid': u'6600842',
#               u'user': u'Danillo Parreira',
#               u'version': u'1'},
#  u'id': u'551739755',
#  u'node_refs': [u'5328188250',
#                 u'5328188251',
#                 u'1761480555',
#                 u'1761480572',
#                 u'5328188250'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb122'),
#  u'caract': {u'amenity': u'school', u'name': u'CEPSS'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:27Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956796',
#  u'node_refs': [u'5329774573',
#                 u'5329774574',
#                 u'5329774575',
#                 u'5329774576',
#                 u'5329774577',
#                 u'5329774578',
#                 u'5329774579',
#                 u'5329774580',
#                 u'5329774581',
#                 u'5329774582',
#                 u'5329774573'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb12f'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:29Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956809',
#  u'node_refs': [u'5329776978',
#                 u'5329776979',
#                 u'5329776980',
#                 u'5329776981',
#                 u'5329776982',
#                 u'5329776983',
#                 u'5329776984',
#                 u'5329776985',
#                 u'5329776986',
#                 u'5329776978'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb131'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:29Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956811',
#  u'node_refs': [u'5329776991',
#                 u'5329776992',
#                 u'5329776993',
#                 u'5329776994',
#                 u'5329776995',
#                 u'5329776996',
#                 u'5329776990',
#                 u'5329776997',
#                 u'5329776991'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb132'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:29Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956812',
#  u'node_refs': [u'5329776998',
#                 u'5329776999',
#                 u'5329777000',
#                 u'5329777001',
#                 u'5329777002',
#                 u'5329777003',
#                 u'5329777004',
#                 u'5329777005',
#                 u'5329776998'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb135'),
#  u'caract': {u'amenity': u'school', u'name': u'Criativa'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:29Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956815',
#  u'node_refs': [u'5329777025',
#                 u'5329777026',
#                 u'5329777027',
#                 u'5329777028',
#                 u'5329777029',
#                 u'5329777030',
#                 u'5329777031',
#                 u'5329777025'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb13c'),
#  u'caract': {u'amenity': u'school', u'name': u'Veritas'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:30Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956822',
#  u'node_refs': [u'5329777077',
#                 u'5329777078',
#                 u'5329777079',
#                 u'5329777080',
#                 u'5329777081',
#                 u'5329777082',
#                 u'5329777083',
#                 u'5329777084',
#                 u'5329777085',
#                 u'5329777077'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb13d'),
#  u'caract': {u'amenity': u'school'},
#  u'created': {u'changeset': u'55299847',
#               u'timestamp': u'2018-01-09T18:00:30Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'551956823',
#  u'node_refs': [u'5329777087',
#                 u'5329777088',
#                 u'5329777089',
#                 u'5329777090',
#                 u'5329777091',
#                 u'5329777092',
#                 u'5329777087'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb149'),
#  u'caract': {u'amenity': u'school', u'name': u'WR'},
#  u'created': {u'changeset': u'55317960',
#               u'timestamp': u'2018-01-10T10:16:27Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'552103189',
#  u'node_refs': [u'5330953079',
#                 u'5330953080',
#                 u'5330953081',
#                 u'5330953082',
#                 u'5330953079'],
#  u'type': u'way'}
# None
# {u'_id': ObjectId('5ac0e4bb659c2a221c5bb14c'),
#  u'caract': {u'amenity': u'school', u'name': u'Ateneu Dom Bosco'},
#  u'created': {u'changeset': u'55317960',
#               u'timestamp': u'2018-01-10T10:16:28Z',
#               u'uid': u'7446788',
#               u'user': u'Jauber',
#               u'version': u'1'},
#  u'id': u'552103192',
#  u'node_refs': [u'5330953088',
#                 u'5330953089',
#                 u'5330953090',
#                 u'5330953091',
#                 u'5330953092',
#                 u'5330953093',
#                 u'5330953094',
#                 u'5330953095',
#                 u'5330953096',
#                 u'5330953097',
#                 u'5330953098',
#                 u'5330953099',
#                 u'5330953088'],
#  u'type': u'way'}
# None

# %%
#amenity: restaurant cousine
print db.goiania.find({"caract.amenity":{"$exists": True, "$eq": u'fast_food'}}).distinct("caract.cuisine")
#most frequent cuisine 
query = []
query.append({"$match":{"caract.amenity":{"$exists": True, "$eq": u'fast_food'}}})
query.append({"$group" : {"_id" : "$caract.cuisine", "count":{"$sum":1}}})
query.append({"$sort" : {"count": -1}})
cuisine = db.goiania.aggregate(query)
for doc in cuisine:
    print pprint.pprint(doc)
# Out:
# [u'burger', u'sandwich', u'burger;arab', u'burger;sandwich', u'pastel;salgados;coca_gelada;sucos;simpatia', u'sandwiches', u'regional;ice_cream', u'pizza;burger']
# {u'_id': None, u'count': 65}
# None
# {u'_id': u'burger', u'count': 6}
# None
# {u'_id': u'sandwich', u'count': 3}
# None
# {u'_id': u'regional;ice_cream', u'count': 1}
# None
# {u'_id': u'sandwiches', u'count': 1}
# None
# {u'_id': u'burger;arab', u'count': 1}
# None
# {u'_id': u'pastel;salgados;coca_gelada;sucos;simpatia', u'count': 1}
# None
# {u'_id': u'burger;sandwich', u'count': 1}
# None
# {u'_id': u'pizza;burger', u'count': 1}
# None
